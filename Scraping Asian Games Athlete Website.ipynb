# %%
# import libraries
import urllib.request # ada juga import urllib.error
from bs4 import BeautifulSoup

from requests import get #beda dengan urllib.request

import pandas as pd

import string
import re

import math

# %%
from time import sleep
import time
from random import randint

from IPython.core.display import clear_output

# %%
#Medallists page
all_url = 'https://en.asiangames2018.id/medals/winners/'
response = get(all_url)
medallists_soup = BeautifulSoup(response.text, 'html.parser')
table = medallists_soup.find_all('table')

# %%
table
# Out:
# [<table class="or-tbl or-tbl-medals or-medal-winners" data-or-analytics-intcmp="medallists-page" id="or-tbl-medallist" summary="Medallists">
#  <thead>
#  <tr>
#  <th class="or-rk" scope="col"> </th>
#  <th class="or-ath-col" scope="col">
#                                      Athlete
#                                  </th>
#  <th class="or-tb-sp or-p1" scope="col">
#                                      Sports
#                                  </th>
#  <th class="or-md or-gold" scope="col" title="Gold Medal">
#  <span class="or-icon or-team-medal or-medal or-gold">
#  <span class="sr-only">Gold Medal</span>
#  <abbr title="Gold Medal">
#                                              G
#                                          </abbr>
#  </span>
#  </th>
#  <th class="or-md or-silver" scope="col" title="Silver Medal">
#  <span class="or-icon or-team-medal or-medal or-silver">
#  <span class="sr-only">Silver Medal</span>
#  <abbr title="Silver Medal">
#                                              S
#                                          </abbr>
#  </span>
#  </th>
#  <th class="or-md or-bronze" scope="col" title="Bronze Medal">
#  <span class="or-icon or-team-medal or-medal or-bronze">
#  <span class="sr-only">Bronze Medal</span>
#  <abbr title="Bronze Medal">
#                                              B
#                                          </abbr>
#  </span>
#  </th>
#  <th aria-label="Total" class="or-med-total" data-js-sortable="false" scope="col" title="Total">
#  <span class="sr-only">Total</span>
#  <span class="or-hdr-l">
#                                          Total
#                                      </span>
#  <abbr class="or-hdr-s" title="Total">
#                                          Tot
#                                      </abbr>
#  </th>
#  </tr>
#  </thead>
#  <tbody data-jshook="tbody">
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              1
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Japan" class="or-fgs" src="/d3images/ml/flags/s/JPN.png" title="Japan"/>
#  <abbr class="or-country-triname" title="Japan">JPN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/IKEE-Rikako-3006657/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="IKEE Rikako" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3006657.png" title="IKEE Rikako"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">RIKAKO</span>
#  <span class="or-surname">IKEE</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          6
#                                      </td>
#  <td class="or-md or-silver">
#                                          2
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          8
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              2
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="China" class="or-fgs" src="/d3images/ml/flags/s/CHN.png" title="China"/>
#  <abbr class="or-country-triname" title="China">CHN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/XU-Jiayu-3008858/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="XU Jiayu" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gM.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3008858.png" title="XU Jiayu"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">JIAYU</span>
#  <span class="or-surname">XU</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          5
#                                      </td>
#  <td class="or-md or-silver">
#                                          0
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          5
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              3
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="China" class="or-fgs" src="/d3images/ml/flags/s/CHN.png" title="China"/>
#  <abbr class="or-country-triname" title="China">CHN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/SUN-Yang-3008844/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="SUN Yang" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gM.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3008844.png" title="SUN Yang"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">YANG</span>
#  <span class="or-surname">SUN</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          4
#                                      </td>
#  <td class="or-md or-silver">
#                                          2
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          6
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              4
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="China" class="or-fgs" src="/d3images/ml/flags/s/CHN.png" title="China"/>
#  <abbr class="or-country-triname" title="China">CHN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/WANG-Jianjiahe-3009432/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="WANG Jianjiahe" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3009432.png" title="WANG Jianjiahe"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">JIANJIAHE</span>
#  <span class="or-surname">WANG</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          4
#                                      </td>
#  <td class="or-md or-silver">
#                                          0
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          4
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              4
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Republic of Korea" class="or-fgs" src="/d3images/ml/flags/s/KOR.png" title="Republic of Korea"/>
#  <abbr class="or-country-triname" title="Republic of Korea">KOR</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/NA-Ahreum-3013080/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="NA Ahreum" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3013080.png" title="NA Ahreum"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">AHREUM</span>
#  <span class="or-surname">NA</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Cycling Road" class="or-sport-name" href="/sport/cycling-road" title="Cycling Road">
#  <span class="or-pic or-cr"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          4
#                                      </td>
#  <td class="or-md or-silver">
#                                          0
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          4
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              6
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Japan" class="or-fgs" src="/d3images/ml/flags/s/JPN.png" title="Japan"/>
#  <abbr class="or-country-triname" title="Japan">JPN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/KOSEKI-Yasuhiro-3026148/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="KOSEKI Yasuhiro" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gM.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3026148.png" title="KOSEKI Yasuhiro"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">YASUHIRO</span>
#  <span class="or-surname">KOSEKI</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          3
#                                      </td>
#  <td class="or-md or-silver">
#                                          2
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          5
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              7
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Japan" class="or-fgs" src="/d3images/ml/flags/s/JPN.png" title="Japan"/>
#  <abbr class="or-country-triname" title="Japan">JPN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/SAKAI-Natsumi-3026169/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="SAKAI Natsumi" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3026169.png" title="SAKAI Natsumi"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">NATSUMI</span>
#  <span class="or-surname">SAKAI</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Swimming" class="or-sport-name" href="/sport/swimming" title="Swimming">
#  <span class="or-pic or-sw"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          3
#                                      </td>
#  <td class="or-md or-silver">
#                                          1
#                                      </td>
#  <td class="or-md or-bronze">
#                                          1
#                                      </td>
#  <td class="or-md or-total">
#                                          5
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              8
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Bahrain" class="or-fgs" src="/d3images/ml/flags/s/BRN.png" title="Bahrain"/>
#  <abbr class="or-country-triname" title="Bahrain">BRN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/ODIONG-Edidiong-3010983/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="ODIONG Edidiong" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3010983.png" title="ODIONG Edidiong"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">Edidiong</span>
#  <span class="or-surname">Odiong</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Athletics" class="or-sport-name" href="/sport/athletics" title="Athletics">
#  <span class="or-pic or-at"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          3
#                                      </td>
#  <td class="or-md or-silver">
#                                          1
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          4
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              8
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="Bahrain" class="or-fgs" src="/d3images/ml/flags/s/BRN.png" title="Bahrain"/>
#  <abbr class="or-country-triname" title="Bahrain">BRN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/NASER-Salwa-3010985/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="NASER Salwa" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3010985.png" title="NASER Salwa"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">Salwa</span>
#  <span class="or-surname">Naser</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Athletics" class="or-sport-name" href="/sport/athletics" title="Athletics">
#  <span class="or-pic or-at"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          3
#                                      </td>
#  <td class="or-md or-silver">
#                                          1
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          4
#                                      </td>
#  </tr>
#  <tr class="or-e" data-jshook="row">
#  <td class="or-rk">
#  <span class="orp-rk">
#                                              10
#                                          </span>
#  </td>
#  <th class="or-ath-col" scope="row">
#  <div class="or-ath-med or-js-or-gm">
#  <span aria-hidden="true" class="or-ath-info">
#  <span class="or-ath-country">
#  <img alt="China" class="or-fgs" src="/d3images/ml/flags/s/CHN.png" title="China"/>
#  <abbr class="or-country-triname" title="China">CHN</abbr>
#  </span>
#  </span>
#  <a class="or-js-w-lk" href="/athletes/athlete/CHEN-Yile-3008271/">
#  <span class="or-ath-ph">
#  <figure class="or-img-l">
#  <img alt="CHEN Yile" class="or-g" onerror="this.src = 'https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gW.svg';" src="https://externalmodules.asiangames2018.id/en/25/images/athletes/l/3008271.png" title="CHEN Yile"/>
#  </figure>
#  </span>
#  <span class="or-ath-name">
#  <span class="or-name">Yile</span>
#  <span class="or-surname">Chen</span>
#  </span>
#  </a>
#  </div>
#  </th>
#  <td class="or-p1">
#  <a aria-label="Artistic Gymnastics" class="or-sport-name" href="/sport/artistic-gymnastic" title="Artistic Gymnastics">
#  <span class="or-pic or-ga"> </span>
#  </a>
#  </td>
#  <td class="or-md or-gold">
#                                          3
#                                      </td>
#  <td class="or-md or-silver">
#                                          0
#                                      </td>
#  <td class="or-md or-bronze">
#                                          0
#                                      </td>
#  <td class="or-md or-total">
#                                          3
#                                      </td>
#  </tr>
#  </tbody>
#  </table>]

# %%
medallists = medallists_soup.find_all('tr', class_ = 'or-e')

# %%
print(len(medallists))
# Out:
# 10

# %%
records = []
for winner in medallists:
    rank = winner.find('span', class_ = 'orp-rk').text
    country = winner.find('img', class_ = 'or-fgs')['title']
    url = 'https://en.asiangames2018.id' + winner.find('a', class_ = 'or-js-w-lk')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya
    name = winner.find('span', class_ = 'or-name').text
    surname = winner.find('span', class_ = 'or-surname').text
    sport = winner.find('a', class_ = 'or-sport-name')['title']
    gold = winner.find('td', class_ = 'or-md or-gold').text
    silver = winner.find('td', class_ = 'or-md or-gold').text
    bronze = winner.find('td', class_ = 'or-md or-silver').text
    medals = winner.find('td', class_ = 'or-md or-total').text
    
    rank = rank.replace(' ', '')
    rank = rank.replace('\r\n', '')
    gold = gold.replace(' ', '')
    gold = gold.replace('\r\n', '')
    silver = silver.replace(' ', '')
    silver = silver.replace('\r\n', '')
    bronze = bronze.replace(' ', '')
    bronze = bronze.replace('\r\n', '')
    medals = medals.replace(' ', '')
    medals = medals.replace('\r\n', '')

    records.append((rank, name, surname, country, sport, gold, silver, bronze, medals, url))

# %%
records
# Out:
# [('1',
#   'RIKAKO',
#   'IKEE',
#   'Japan',
#   'Swimming',
#   '6',
#   '6',
#   '2',
#   '8',
#   'https://en.asiangames2018.id/athletes/athlete/IKEE-Rikako-3006657/'),
#  ('2',
#   'JIAYU',
#   'XU',
#   'China',
#   'Swimming',
#   '5',
#   '5',
#   '0',
#   '5',
#   'https://en.asiangames2018.id/athletes/athlete/XU-Jiayu-3008858/'),
#  ('3',
#   'YANG',
#   'SUN',
#   'China',
#   'Swimming',
#   '4',
#   '4',
#   '2',
#   '6',
#   'https://en.asiangames2018.id/athletes/athlete/SUN-Yang-3008844/'),
#  ('4',
#   'JIANJIAHE',
#   'WANG',
#   'China',
#   'Swimming',
#   '4',
#   '4',
#   '0',
#   '4',
#   'https://en.asiangames2018.id/athletes/athlete/WANG-Jianjiahe-3009432/'),
#  ('4',
#   'AHREUM',
#   'NA',
#   'Republic of Korea',
#   'Cycling Road',
#   '4',
#   '4',
#   '0',
#   '4',
#   'https://en.asiangames2018.id/athletes/athlete/NA-Ahreum-3013080/'),
#  ('6',
#   'YASUHIRO',
#   'KOSEKI',
#   'Japan',
#   'Swimming',
#   '3',
#   '3',
#   '2',
#   '5',
#   'https://en.asiangames2018.id/athletes/athlete/KOSEKI-Yasuhiro-3026148/'),
#  ('7',
#   'NATSUMI',
#   'SAKAI',
#   'Japan',
#   'Swimming',
#   '3',
#   '3',
#   '1',
#   '5',
#   'https://en.asiangames2018.id/athletes/athlete/SAKAI-Natsumi-3026169/'),
#  ('8',
#   'Edidiong',
#   'Odiong',
#   'Bahrain',
#   'Athletics',
#   '3',
#   '3',
#   '1',
#   '4',
#   'https://en.asiangames2018.id/athletes/athlete/ODIONG-Edidiong-3010983/'),
#  ('8',
#   'Salwa',
#   'Naser',
#   'Bahrain',
#   'Athletics',
#   '3',
#   '3',
#   '1',
#   '4',
#   'https://en.asiangames2018.id/athletes/athlete/NASER-Salwa-3010985/'),
#  ('10',
#   'Yile',
#   'Chen',
#   'China',
#   'Artistic Gymnastics',
#   '3',
#   '3',
#   '0',
#   '3',
#   'https://en.asiangames2018.id/athletes/athlete/CHEN-Yile-3008271/')]

# %%
df = pd.DataFrame(records, columns =['rank', 'name', 'surname', 'country', 'sport', 'gold', 'silver', 'bronze', 'medals', 'url'])

# %%
df
# Out:
#   rank       name surname            country                sport gold silver  \
# 0    1     RIKAKO    IKEE              Japan             Swimming    6      6
# 1    2      JIAYU      XU              China             Swimming    5      5
# 2    3       YANG     SUN              China             Swimming    4      4
# 3    4  JIANJIAHE    WANG              China             Swimming    4      4
# 4    4     AHREUM      NA  Republic of Korea         Cycling Road    4      4
# 5    6   YASUHIRO  KOSEKI              Japan             Swimming    3      3
# 6    7    NATSUMI   SAKAI              Japan             Swimming    3      3
# 7    8   Edidiong  Odiong            Bahrain            Athletics    3      3
# 8    8      Salwa   Naser            Bahrain            Athletics    3      3
# 9   10       Yile    Chen              China  Artistic Gymnastics    3      3
#
#   bronze medals                                                url
# 0      2      8  https://en.asiangames2018.id/athletes/athlete/...
# 1      0      5  https://en.asiangames2018.id/athletes/athlete/...
# 2      2      6  https://en.asiangames2018.id/athletes/athlete/...
# 3      0      4  https://en.asiangames2018.id/athletes/athlete/...
# 4      0      4  https://en.asiangames2018.id/athletes/athlete/...
# 5      2      5  https://en.asiangames2018.id/athletes/athlete/...
# 6      1      5  https://en.asiangames2018.id/athletes/athlete/...
# 7      1      4  https://en.asiangames2018.id/athletes/athlete/...
# 8      1      4  https://en.asiangames2018.id/athletes/athlete/...
# 9      0      3  https://en.asiangames2018.id/athletes/athlete/...

# %% [markdown]
# # Changing the URLs parameter

# %%
# Overall
pages = [str(i) for i in range(1,151)]

# %%
start_time = time.time()
requests = 0

# %%
all_ = []
for page in pages:
    all_url = 'https://en.asiangames2018.id/medals/winners/libraries/' + page + '/_overall'
    
    response = get(all_url)

    sleep(randint(8,15))
    
    
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
    
    medallists_soup = BeautifulSoup(response.text, 'html.parser')
    
    medallists = medallists_soup.find_all('tr', class_ = 'or-e')
    
    for winner in medallists:
        rank = winner.find('span', class_ = 'orp-rk').text
        country = winner.find('img', class_ = 'or-fgs')['title']
        url = 'https://en.asiangames2018.id' + winner.find('a', class_ = 'or-js-w-lk')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya
        name = winner.find('span', class_ = 'or-name').text
        surname = winner.find('span', class_ = 'or-surname').text
        sport = winner.find('a', class_ = 'or-sport-name')['title']
        gold = winner.find('td', class_ = 'or-md or-gold').text
        silver = winner.find('td', class_ = 'or-md or-silver').text
        bronze = winner.find('td', class_ = 'or-md or-bronze').text
        medals = winner.find('td', class_ = 'or-md or-total').text
    
        rank = rank.replace(' ', '')
        rank = rank.replace('\r\n', '')
        gold = gold.replace(' ', '')
        gold = gold.replace('\r\n', '')
        silver = silver.replace(' ', '')
        silver = silver.replace('\r\n', '')
        bronze = bronze.replace(' ', '')
        bronze = bronze.replace('\r\n', '')
        medals = medals.replace(' ', '')
        medals = medals.replace('\r\n', '')

        all_.append((int(rank), name, surname, country, sport, int(gold), int(silver), int(bronze), int(medals), url))
# Out:
# Request:150; Frequency: 0.08073295646169452 requests/s

# %%
all_df = pd.DataFrame(all_, columns =['rank', 'name', 'surname', 'country', 'sport', 'gold', 'silver', 'bronze', 'medals', 'url'])

# %%
all_df.to_csv('ag2018_medallists.csv', index=False)

# %% [markdown]
# ## Men

# %%
# Men only
pages = [str(i) for i in range(1,151)]

# %%
start_time = time.time()
requests = 0

# %%
men = []
for page in pages:
    men_url = 'https://en.asiangames2018.id/medals/winners/libraries/' + page + '/_men'
    
    response = get(men_url)

    sleep(randint(8,15))
    
    
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
    
    medallists_soup = BeautifulSoup(response.text, 'html.parser')
    
    medallists = medallists_soup.find_all('tr', class_ = 'or-e')
    
    for winner in medallists:
        rank = winner.find('span', class_ = 'orp-rk').text
        country = winner.find('img', class_ = 'or-fgs')['title']
        url = 'https://en.asiangames2018.id' + winner.find('a', class_ = 'or-js-w-lk')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya
        name = winner.find('span', class_ = 'or-name').text
        surname = winner.find('span', class_ = 'or-surname').text
        sport = winner.find('a', class_ = 'or-sport-name')['title']
        gold = winner.find('td', class_ = 'or-md or-gold').text
        silver = winner.find('td', class_ = 'or-md or-silver').text
        bronze = winner.find('td', class_ = 'or-md or-bronze').text
        medals = winner.find('td', class_ = 'or-md or-total').text
    
        rank = rank.replace(' ', '')
        rank = rank.replace('\r\n', '')
        gold = gold.replace(' ', '')
        gold = gold.replace('\r\n', '')
        silver = silver.replace(' ', '')
        silver = silver.replace('\r\n', '')
        bronze = bronze.replace(' ', '')
        bronze = bronze.replace('\r\n', '')
        medals = medals.replace(' ', '')
        medals = medals.replace('\r\n', '')

        men.append((int(rank), name, surname, country, sport, int(gold), int(silver), int(bronze), int(medals), url))
# Out:
# Request:150; Frequency: 0.07793071861933223 requests/s

# %%
men_df = pd.DataFrame(men, columns =['rank', 'name', 'surname', 'country', 'sport', 'gold', 'silver', 'bronze', 'medals', 'url'])

# %%
men_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
# rank       1500 non-null int64
# name       1500 non-null object
# surname    1500 non-null object
# country    1500 non-null object
# sport      1500 non-null object
# gold       1500 non-null int64
# silver     1500 non-null int64
# bronze     1500 non-null int64
# medals     1500 non-null int64
# url        1500 non-null object
# dtypes: int64(5), object(5)
# memory usage: 117.3+ KB

# %%
men_df.to_csv('ag2018_men_medallists.csv', index=False)

# %% [markdown]
# ## Women

# %%
# Women only
pages_wm = [str(i) for i in range(1,148)]

# %%
start_time = time.time()
requests = 0

# %%
women = []
for page in pages_wm:
    women_url = 'https://en.asiangames2018.id/medals/winners/libraries/' + page + '/_women'
    
    response = get(women_url)

    sleep(randint(8,15))
    
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
    
    medallists_soup = BeautifulSoup(response.text, 'html.parser')
    
    medallists = medallists_soup.find_all('tr', class_ = 'or-e')
    
    for winner in medallists:
        rank = winner.find('span', class_ = 'orp-rk').text
        country = winner.find('img', class_ = 'or-fgs')['title']
        url = 'https://en.asiangames2018.id' + winner.find('a', class_ = 'or-js-w-lk')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya
        name = winner.find('span', class_ = 'or-name').text
        surname = winner.find('span', class_ = 'or-surname').text
        sport = winner.find('a', class_ = 'or-sport-name')['title']
        gold = winner.find('td', class_ = 'or-md or-gold').text
        silver = winner.find('td', class_ = 'or-md or-silver').text
        bronze = winner.find('td', class_ = 'or-md or-bronze').text
        medals = winner.find('td', class_ = 'or-md or-total').text
    
        rank = rank.replace(' ', '')
        rank = rank.replace('\r\n', '')
        gold = gold.replace(' ', '')
        gold = gold.replace('\r\n', '')
        silver = silver.replace(' ', '')
        silver = silver.replace('\r\n', '')
        bronze = bronze.replace(' ', '')
        bronze = bronze.replace('\r\n', '')
        medals = medals.replace(' ', '')
        medals = medals.replace('\r\n', '')

        women.append((int(rank), name, surname, country, sport, int(gold), int(silver), int(bronze), int(medals), url))
# Out:
# Request:147; Frequency: 0.07995449767566495 requests/s

# %%
women_df = pd.DataFrame(women, columns =['rank', 'name', 'surname', 'country', 'sport', 'gold', 'silver', 'bronze', 'medals', 'url'])

# %%
women_df.to_csv('ag2018_women_medallists.csv', index=False)

# %% [markdown]
# # Country

# %%
country_ = []
medals_url = 'https://en.asiangames2018.id/medals/'
response = get(medals_url)
country_soup = BeautifulSoup(response.text, 'html.parser')
country_medal = country_soup.find_all('tr', class_ = 'or-ses-list or-js-sch-active orp-plugin')
for country in country_medal:
    rank = country.find('span', class_ = 'orp-rk').text
    id_ = country.find('span', class_ = 'or-team-n').text
    country_name = country.find('span', class_ = 'or-team-n')['title']
    gold = country.find('td', class_ = 'or-md or-gold').text
    silver = country.find('td', class_ = 'or-md or-silver').text
    bronze = country.find('td', class_ = 'or-md or-bronze').text
    medals = country.find('td', class_ = 'or-md or-total or-l').text
    url = 'https://en.asiangames2018.id' + country['data-href']
    
    rank = rank.replace(' ', '')
    rank = rank.replace('\r\n', '')
    gold = gold.replace(' ', '')
    gold = gold.replace('\r\n', '')
    silver = silver.replace(' ', '')
    silver = silver.replace('\r\n', '')
    bronze = bronze.replace(' ', '')
    bronze = bronze.replace('\r\n', '')
    medals = medals.replace(' ', '')
    medals = medals.replace('\r\n', '')

    country_.append((int(rank), id_, country_name, int(gold), int(silver), int(bronze), int(medals), url))
    
country_df = pd.DataFrame(country_, columns =['rank', 'id', 'country_name', 'gold', 'silver', 'bronze', 'medals', 'url'])

# %%
country_df.to_csv('ag2018_country_medal_table.csv', index=False)

# %% [markdown]
# ## per Country

# %%
country_df = pd.read_csv('ag2018_country_medal_table.csv')

# %%
for i in range(0, len(country_df)):
    sport_ = []
    url = country_df['url'][i]
    response = get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    sport_medal = soup.find_all('tr', class_ = 'or-e or-table-list or-table-list-groupedRow')
    for sport in sport_medal:
        name = sport.find('span', class_ = 'or-text').text
        gold = sport.find('td', class_ = 'or-md or-gold').text
        silver = sport.find('td', class_ = 'or-md or-silver').text
        bronze = sport.find('td', class_ = 'or-md or-bronze').text
        medals = sport.find('td', class_ = 'or-md or-total').text
        
        sport_.append((name, int(gold), int(silver), int(bronze), int(medals)))
    
    sport_df = pd.DataFrame(sport_, columns = ['sport_name', 'gold', 'silver', 'bronze', 'total_medals'])
    name_file = 'AG2018_country_medals\\ag2018_' + str(country_df['rank'][i]) + '.' + country_df['id'][i] + '_medal_table.csv'
    sport_df.to_csv(name_file, index = False)

# %% [markdown]
# # Athletes

# %%
women_df = pd.read_csv('ag2018_women_medallists.csv')

# %%
women_df.head()
# Out:
#    rank       name surname            country         sport  gold  silver  \
# 0     1     RIKAKO    IKEE              Japan      Swimming     6       2
# 1     2  JIANJIAHE    WANG              China      Swimming     4       0
# 2     2     AHREUM     NaN  Republic of Korea  Cycling Road     4       0
# 3     4    NATSUMI   SAKAI              Japan      Swimming     3       1
# 4     5   Edidiong  Odiong            Bahrain     Athletics     3       1
#
#    bronze  medals                                                url
# 0       0       8  https://en.asiangames2018.id/athletes/athlete/...
# 1       0       4  https://en.asiangames2018.id/athletes/athlete/...
# 2       0       4  https://en.asiangames2018.id/athletes/athlete/...
# 3       1       5  https://en.asiangames2018.id/athletes/athlete/...
# 4       0       4  https://en.asiangames2018.id/athletes/athlete/...

# %%
women_df.describe()
# Out:
#               rank         gold       silver       bronze       medals
# count  1462.000000  1462.000000  1462.000000  1462.000000  1462.000000
# mean    546.692886     0.360465     0.364569     0.458276     1.183311
# std     346.700161     0.576184     0.515791     0.538049     0.513255
# min       1.000000     0.000000     0.000000     0.000000     1.000000
# 25%     132.000000     0.000000     0.000000     0.000000     1.000000
# 50%     539.000000     0.000000     0.000000     0.000000     1.000000
# 75%     941.000000     1.000000     1.000000     1.000000     1.000000
# max     941.000000     6.000000     3.000000     3.000000     8.000000

# %%
athlete = []
requests = 0
start_time = time.time()

for i in range(0, len(women_df)):
    bio = []
    social = []
    
    ath_url = women_df['url'][i]
    ath_response = get(ath_url)
    ath_soup = BeautifulSoup(ath_response.text, 'html.parser')

    
    sleep(randint(1,4))
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)    
    
    name = ath_soup.find('span', class_ = 'or-athlete-profile__name--name').text
    surname = ath_soup.find('span', class_ = 'or-athlete-profile__name--surname').text
    nationality = ath_soup.find('span', class_ = 'or-athlete-profile__nationality--noc').text
    discipline = ath_soup.find('div', class_ = 'or-athlete-profile__discipline').text
    birth_date = ath_soup.find('span', class_ = 'or-athlete__birth--date').text
    birth_city = ath_soup.find('span', class_ = 'or-athlete__birth--city').text
    
    if ath_soup.find('span', class_ = 'or-athlete__birth--country') is not None:
        birth_country = ath_soup.find('span', class_ = 'or-athlete__birth--country').text
    else: birth_country = ''
    
    age = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[0].text
    height = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[2].text
    weight = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[3].text
    
    birth_country = birth_country[1:-1]
    age = age.replace(' ', '')
    age = age.replace('\r\n', '')
    height = height.replace(' ', '')
    height = height.replace('\r', '')
    height = height.replace('\n', '')
    if (height == '-/-'):
        height_cm = ''
        height = ''
    else:
        height_cm = height[0:height.find("CM")] #kalau height = '-/...' atau height.find("CM") == -1, maka akan menyimpan nilai '-/'
        height = height[len(height_cm) + 3:] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    weight = weight.replace(' ', '')
    weight = weight.replace('\r', '')
    weight = weight.replace('\n', '')
    if (weight == '-/-'):
        weight_kg = ''
        weight_lbs = ''
    else:
        weight_kg = weight[0:weight.find("kg")] #kalau weight = '-/...' atau weight.find("kg") == -1, maka akan menyimpan nilai '-/'
        weight_lbs = weight[weight.find("kg") + 3:weight.find("lbs")] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    
    
    src_containers = ath_soup.find_all('orp')
    
    medal_containers = src_containers[0]
    ath_medal_url = medal_containers['src']


    sleep(randint(1,2))

    
    response = get(ath_medal_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup.find_all('td', class_ = 'or-table-medals__b--medal') != []:
        gold = soup.find_all('td', class_ = 'or-table-medals__b--medal')[0].text
        silver = soup.find_all('td', class_ = 'or-table-medals__b--medal')[1].text
        bronze = soup.find_all('td', class_ = 'or-table-medals__b--medal')[2].text
    else:
        gold = 0
        silver = 0
        bronze = 0
    
    bio_containers = src_containers[1]
    bio_url = bio_containers['src']
    bio_response = get(bio_url)
    bio_soup = BeautifulSoup(bio_response.text, 'html.parser')


    sleep(randint(1,2))

    
    bio_containers = bio_soup.find_all('div', class_ ='or-article__part markdown')
    
    for j in range(0, len(bio_containers)):
        subtitle = bio_containers[j].h2.text #Perlu lebih dirapikan di bagian ini
        content = bio_containers[j].p.text #ada b, ada br, ada \n
        if (subtitle == 'Social'):
            socmed_containers = bio_containers[j].find_all('li')
            for k in range(0, len(socmed_containers)):
                social.append((socmed_containers[k].a['href']))
        else:
            bio.append((subtitle, content))
        
        
    athlete.append((ath_url, name, surname, nationality, discipline, birth_date, birth_city, birth_country, age, height_cm, height, weight_kg, weight_lbs, int(gold), int(silver), int(bronze), bio, social, bio_url))
    #height_cm, weight_kg, dan weight_lbs belum jadi int karena bisa berisikan '-' #kasus #351
    #age belum jadi int karena berisikan '\n' #kasus #768
# Out:
# Request:1462; Frequency: 0.09511085878434283 requests/s

# %%
len(athlete)
# Out:
# 1462

# %% [markdown]
# ### top 100 overall medallists

# %%
athlete_top100_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'bio_url'])
athlete_top100_df.to_csv('ag2018_athlete_top100.csv', index = False)

# %% [markdown]
# ### all women medallists

# %%
athlete_women_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'social', 'bio_url'])
athlete_women_df.to_csv('ag2018_athlete_women_medallists.csv', index = False)

# %%
men_df = pd.read_csv('ag2018_men_medallists.csv')

# %%
athlete = []
requests = 0
start_time = time.time()

for i in range(0, len(men_df)):
    bio = []
    social = []
    
    ath_url = men_df['url'][i]
    ath_response = get(ath_url)
    ath_soup = BeautifulSoup(ath_response.text, 'html.parser')

    
    sleep(randint(1,4))
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)    
    
    name = ath_soup.find('span', class_ = 'or-athlete-profile__name--name').text
    surname = ath_soup.find('span', class_ = 'or-athlete-profile__name--surname').text
    nationality = ath_soup.find('span', class_ = 'or-athlete-profile__nationality--noc').text
    discipline = ath_soup.find('div', class_ = 'or-athlete-profile__discipline').text
    birth_date = ath_soup.find('span', class_ = 'or-athlete__birth--date').text
    birth_city = ath_soup.find('span', class_ = 'or-athlete__birth--city').text
    
    if ath_soup.find('span', class_ = 'or-athlete__birth--country') is not None:
        birth_country = ath_soup.find('span', class_ = 'or-athlete__birth--country').text
    else: birth_country = ''
    
    age = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[0].text
    height = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[2].text
    weight = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[3].text
    
    birth_country = birth_country[1:-1]
    age = age.replace(' ', '')
    age = age.replace('\r\n', '')
    height = height.replace(' ', '')
    height = height.replace('\r', '')
    height = height.replace('\n', '')
    if (height == '-/-'):
        height_cm = ''
        height = ''
    else:
        height_cm = height[0:height.find("CM")] #kalau height = '-/...' atau height.find("CM") == -1, maka akan menyimpan nilai '-/'
        height = height[len(height_cm) + 3:] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    weight = weight.replace(' ', '')
    weight = weight.replace('\r', '')
    weight = weight.replace('\n', '')
    if (weight == '-/-'):
        weight_kg = ''
        weight_lbs = ''
    else:
        weight_kg = weight[0:weight.find("kg")] #kalau weight = '-/...' atau weight.find("kg") == -1, maka akan menyimpan nilai '-/'
        weight_lbs = weight[weight.find("kg") + 3:weight.find("lbs")] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    
    
    src_containers = ath_soup.find_all('orp')
    
    medal_containers = src_containers[0]
    ath_medal_url = medal_containers['src']


    sleep(randint(1,2))

    
    response = get(ath_medal_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup.find_all('td', class_ = 'or-table-medals__b--medal') != []:
        gold = soup.find_all('td', class_ = 'or-table-medals__b--medal')[0].text
        silver = soup.find_all('td', class_ = 'or-table-medals__b--medal')[1].text
        bronze = soup.find_all('td', class_ = 'or-table-medals__b--medal')[2].text
    else:
        gold = 0
        silver = 0
        bronze = 0
    
    bio_containers = src_containers[1]
    bio_url = bio_containers['src']
    bio_response = get(bio_url)
    bio_soup = BeautifulSoup(bio_response.text, 'html.parser')


    sleep(randint(1,2))

    
    bio_containers = bio_soup.find_all('div', class_ ='or-article__part markdown')
    
    for j in range(0, len(bio_containers)):
        subtitle = bio_containers[j].h2.text #Perlu lebih dirapikan di bagian ini
        content = bio_containers[j].p.text #ada b, ada br, ada \n
        if (subtitle == 'Social'):
            socmed_containers = bio_containers[j].find_all('li')
            for k in range(0, len(socmed_containers)):
                social.append((socmed_containers[k].a['href']))
        else:
            bio.append((subtitle, content))
        
        
    athlete.append((ath_url, name, surname, nationality, discipline, birth_date, birth_city, birth_country, age, height_cm, height, weight_kg, weight_lbs, int(gold), int(silver), int(bronze), bio, social, bio_url))
    #height_cm, weight_kg, dan weight_lbs belum jadi int karena bisa berisikan '-' #kasus #351
    #age belum jadi int karena berisikan '\n' #kasus #768
# Out:
# Request:1500; Frequency: 0.13801662410734908 requests/s

# %%
len(athlete)
# Out:
# 1500

# %%
athlete_men_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'social', 'bio_url'])
athlete_men_df.to_csv('ag2018_athlete_men_medallists.csv', index = False)

# %% [markdown]
# # Sport Athletes

# %%
athlete_url = 'https://en.asiangames2018.id/athletes/page/1/'

# Make a list of sports' code
response = get(athlete_url)
soup = BeautifulSoup(response.text, 'html.parser')

sport_containers = soup.find_all('li', class_ = 'or-picto or-sportshub__item ')

sport_ = []
for sport in sport_containers:
    sp_name = sport.find('div', class_ = 'or-res-disc-name').text
    sp_ath_no = sport.find('div', class_ = 'or-res-disc-athletes').text
    sp_ath_no = sp_ath_no[0:sp_ath_no.find(" ")]
    sp_ath_url = 'https://en.asiangames2018.id' + sport.find('a')['href']
    sp_code = sport.find('a')['href'][16:18]
    page_no = math.ceil(int(sp_ath_no)/12)
    sport_.append((sp_ath_url, sp_code, sp_name, sp_ath_no, page_no))
    
sport_df = pd.DataFrame(sport_, columns = ['sp_url', 'sp_code', 'sport_name', 'no_athlete_sp', 'page_no'])
sport_df.to_csv('ag2018_sport_athlete_summary.csv', index = False)

# %%
sport_df
# Out:
#                                                sp_url sp_code  \
# 0   https://en.asiangames2018.id/athletes/sport/AR...      AR
# 1   https://en.asiangames2018.id/athletes/sport/GA...      GA
# 2   https://en.asiangames2018.id/athletes/sport/SY...      SY
# 3   https://en.asiangames2018.id/athletes/sport/AT...      AT
# 4   https://en.asiangames2018.id/athletes/sport/BD...      BD
# 5   https://en.asiangames2018.id/athletes/sport/BB...      BB
# 6   https://en.asiangames2018.id/athletes/sport/BK...      BK
# 7   https://en.asiangames2018.id/athletes/sport/B3...      B3
# 8   https://en.asiangames2018.id/athletes/sport/BV...      BV
# 9   https://en.asiangames2018.id/athletes/sport/BO...      BO
# 10  https://en.asiangames2018.id/athletes/sport/BX...      BX
# 11  https://en.asiangames2018.id/athletes/sport/BR...      BR
# 12  https://en.asiangames2018.id/athletes/sport/CS...      CS
# 13  https://en.asiangames2018.id/athletes/sport/CF...      CF
# 14  https://en.asiangames2018.id/athletes/sport/CB...      CB
# 15  https://en.asiangames2018.id/athletes/sport/CM...      CM
# 16  https://en.asiangames2018.id/athletes/sport/CR...      CR
# 17  https://en.asiangames2018.id/athletes/sport/CT...      CT
# 18  https://en.asiangames2018.id/athletes/sport/DV...      DV
# 19  https://en.asiangames2018.id/athletes/sport/EQ...      EQ
# 20  https://en.asiangames2018.id/athletes/sport/FE...      FE
# 21  https://en.asiangames2018.id/athletes/sport/FB...      FB
# 22  https://en.asiangames2018.id/athletes/sport/GO...      GO
# 23  https://en.asiangames2018.id/athletes/sport/HB...      HB
# 24  https://en.asiangames2018.id/athletes/sport/HO...      HO
# 25  https://en.asiangames2018.id/athletes/sport/JS...      JS
# 26  https://en.asiangames2018.id/athletes/sport/JU...      JU
# 27  https://en.asiangames2018.id/athletes/sport/JJ...      JJ
# 28  https://en.asiangames2018.id/athletes/sport/KD...      KD
# 29  https://en.asiangames2018.id/athletes/sport/KA...      KA
# 30  https://en.asiangames2018.id/athletes/sport/KU...      KU
# 31  https://en.asiangames2018.id/athletes/sport/MP...      MP
# 32  https://en.asiangames2018.id/athletes/sport/PG...      PG
# 33  https://en.asiangames2018.id/athletes/sport/PS...      PS
# 34  https://en.asiangames2018.id/athletes/sport/GR...      GR
# 35  https://en.asiangames2018.id/athletes/sport/RS...      RS
# 36  https://en.asiangames2018.id/athletes/sport/RO...      RO
# 37  https://en.asiangames2018.id/athletes/sport/RU...      RU
# 38  https://en.asiangames2018.id/athletes/sport/SA...      SA
# 39  https://en.asiangames2018.id/athletes/sport/SC...      SC
# 40  https://en.asiangames2018.id/athletes/sport/SE...      SE
# 41  https://en.asiangames2018.id/athletes/sport/SH...      SH
# 42  https://en.asiangames2018.id/athletes/sport/SK...      SK
# 43  https://en.asiangames2018.id/athletes/sport/SF...      SF
# 44  https://en.asiangames2018.id/athletes/sport/SO...      SO
# 45  https://en.asiangames2018.id/athletes/sport/CL...      CL
# 46  https://en.asiangames2018.id/athletes/sport/SQ...      SQ
# 47  https://en.asiangames2018.id/athletes/sport/SW...      SW
# 48  https://en.asiangames2018.id/athletes/sport/TT...      TT
# 49  https://en.asiangames2018.id/athletes/sport/TK...      TK
# 50  https://en.asiangames2018.id/athletes/sport/TE...      TE
# 51  https://en.asiangames2018.id/athletes/sport/GT...      GT
# 52  https://en.asiangames2018.id/athletes/sport/TR...      TR
# 53  https://en.asiangames2018.id/athletes/sport/VO...      VO
# 54  https://en.asiangames2018.id/athletes/sport/WP...      WP
# 55  https://en.asiangames2018.id/athletes/sport/WL...      WL
# 56  https://en.asiangames2018.id/athletes/sport/WR...      WR
# 57  https://en.asiangames2018.id/athletes/sport/WU...      WU
#
#                sport_name no_athlete_sp  page_no
# 0                 Archery           268       23
# 1     Artistic Gymnastics           146       13
# 2       Artistic Swimming            99        9
# 3               Athletics           800       67
# 4               Badminton           232       20
# 5                Baseball           233       20
# 6              Basketball           380       32
# 7          Basketball 3x3           178       15
# 8        Beach Volleyball           116       10
# 9                 Bowling           179       15
# 10                 Boxing           207       18
# 11                 Bridge           218       19
# 12     Canoe/Kayak Slalom            57        5
# 13     Canoe/Kayak Sprint           496       42
# 14            Cycling BMX            23        2
# 15  Cycling Mountain Bike            49        5
# 16           Cycling Road            63        6
# 17          Cycling Track           209       18
# 18                 Diving            87        8
# 19             Equestrian           139       12
# 20                Fencing           287       24
# 21               Football           866       73
# 22                   Golf           133       12
# 23               Handball           409       35
# 24                 Hockey           416       35
# 25                 JetSki            36        3
# 26                   Judo           267       23
# 27               Ju-Jitsu           228       19
# 28                Kabaddi           247       21
# 29                 Karate           210       18
# 30                 Kurash           180       15
# 31      Modern Pentathlon            29        3
# 32            Paragliding           109       10
# 33           Pencak Silat           200       17
# 34    Rhythmic Gymnastics            37        4
# 35           Roller Skate            34        3
# 36                 Rowing           424       36
# 37           Rugby Sevens           280       24
# 38                Sailing           150       13
# 39                  Sambo            80        7
# 40            Sepaktakraw           265       23
# 41               Shooting           427       36
# 42             Skateboard            37        4
# 43            Soft Tennis           116       10
# 44               Softball           120       10
# 45         Sport Climbing           137       12
# 46                 Squash           107        9
# 47               Swimming           390       33
# 48           Table Tennis           193       17
# 49              Taekwondo           299       25
# 50                 Tennis           180       15
# 51  Trampoline Gymnastics            20        2
# 52              Triathlon            94        8
# 53             Volleyball           456       38
# 54             Water Polo           229       20
# 55          Weightlifting           185       16
# 56              Wrestling           259       22
# 57                  Wushu           222       19

# %%
sport_df = pd.read_csv('ag2018_sport_athlete_summary.csv')

# %%
for j in range(0, len(sport_df)):
    pages_sp = [str(i) for i in range(1, int(sport_df['page_no'][j]) + 1)]
    
    start_time = time.time()
    requests = 0
    
    sp_ath = []
    
    for page in pages_sp:
        sp_ath_url = 'https://en.asiangames2018.id/athletes/sport/' + sport_df['sp_code'][j] + '/page/' + page + '/'
    
        response = get(sp_ath_url)

        sleep(randint(8,15))
    
        requests += 1
        elapsed_time = time.time() - start_time
        print('Request: {}.{}; Frequency: {} requests/s'.format(j, requests, requests/elapsed_time))
        clear_output(wait = True)
    
        athlete_soup = BeautifulSoup(response.text, 'html.parser')
    
        athletes = athlete_soup.find_all('li', class_ = 'or-athletes__item')
    
        for athlete in athletes:
            fname = athlete.find('div', class_ = 'or-card-athlete__name')['title'] #fname = surname + name
            name = athlete.find('div', class_ = 'or-card-athlete__passport-name').text
            surname = athlete.find('div', class_ = 'or-card-athlete__passport-surname').text
            country = athlete.find('img', class_ = 'or-card-athlete__country-flag')['title']
            noc_code = athlete.find('div', class_ = 'or-card-athlete__country-code').text
            discipline = athlete.find('div', class_ = 'or-card-athlete__discipline').text
            sp_code = sport_df['sp_code'][j]
            url = 'https://en.asiangames2018.id' + athlete.find('a', class_ = 'or-athletes__link')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya

            sp_ath.append((url, fname, name, surname, country, noc_code, discipline, sp_code))
        
    sp_ath_df = pd.DataFrame(sp_ath, columns =['url', 'fullname', 'name', 'surname', 'country', 'noc_code', 'discipline', 'discipline_code'])
    name_file = 'AG2018_sport_athletes\\ag2018_' + str(int(j) + 1) + '.' + sport_df['sport_name'][j].replace(' ', '-').replace('/','-') + '_athletes.csv'
    sp_ath_df.to_csv(name_file, index=False)
# Out:
# Request: 57.19; Frequency: 0.07502071048875548 requests/s

# %%
sp_ath_df = pd.read_csv('AG2018_sport_athletes\\ag2018_' + str(int(j) + 1) + '.' + sport_df['sport_name'][j].replace(' ', '-').replace('/','-') + '_athletes.csv')

# %%
athlete = []
start_time = time.time()
requests = 0

for i in range(0, len(sp_ath_df)):
    bio = []
    social = []
    
    ath_url = sp_ath_df['url'][i]
    ath_response = get(ath_url)
    ath_soup = BeautifulSoup(ath_response.text, 'html.parser')

    
    sleep(randint(1,4))
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)    
    
    name = ath_soup.find('span', class_ = 'or-athlete-profile__name--name').text
    surname = ath_soup.find('span', class_ = 'or-athlete-profile__name--surname').text
    nationality = ath_soup.find('span', class_ = 'or-athlete-profile__nationality--noc').text
    discipline = ath_soup.find('div', class_ = 'or-athlete-profile__discipline').text
    birth_date = ath_soup.find('span', class_ = 'or-athlete__birth--date').text
    birth_city = ath_soup.find('span', class_ = 'or-athlete__birth--city').text
    
    if ath_soup.find('span', class_ = 'or-athlete__birth--country') is not None:
        birth_country = ath_soup.find('span', class_ = 'or-athlete__birth--country').text
    else: birth_country = ''
    
    age = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[0].text
    height = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[2].text
    weight = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[3].text
    
    birth_country = birth_country[1:-1]
    age = age.replace(' ', '')
    age = age.replace('\r\n', '')
    height = height.replace(' ', '')
    height = height.replace('\r', '')
    height = height.replace('\n', '')
    if (height == '-/-'):
        height_cm = ''
        height = ''
    else:
        height_cm = height[0:height.find("CM")] #kalau height = '-/...' atau height.find("CM") == -1, maka akan menyimpan nilai '-/'
        height = height[len(height_cm) + 3:] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    weight = weight.replace(' ', '')
    weight = weight.replace('\r', '')
    weight = weight.replace('\n', '')
    if (weight == '-/-'):
        weight_kg = ''
        weight_lbs = ''
    else:
        weight_kg = weight[0:weight.find("kg")] #kalau weight = '-/...' atau weight.find("kg") == -1, maka akan menyimpan nilai '-/'
        weight_lbs = weight[weight.find("kg") + 3:weight.find("lbs")] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    
    
    src_containers = ath_soup.find_all('orp')
    
    medal_containers = src_containers[0]
    ath_medal_url = medal_containers['src']


    sleep(randint(1,2))

    
    response = get(ath_medal_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup.find_all('td', class_ = 'or-table-medals__b--medal') != []:
        gold = soup.find_all('td', class_ = 'or-table-medals__b--medal')[0].text
        silver = soup.find_all('td', class_ = 'or-table-medals__b--medal')[1].text
        bronze = soup.find_all('td', class_ = 'or-table-medals__b--medal')[2].text
    else:
        gold = 0
        silver = 0
        bronze = 0
    
    bio_containers = src_containers[1]
    bio_url = bio_containers['src']
    bio_response = get(bio_url)
    bio_soup = BeautifulSoup(bio_response.text, 'html.parser')


    sleep(randint(1,2))

    
    bio_containers = bio_soup.find_all('div', class_ ='or-article__part markdown')
    
    for j in range(0, len(bio_containers)):
        subtitle = bio_containers[j].h2.text #Perlu lebih dirapikan di bagian ini
        content = bio_containers[j].p.text #ada b, ada br, ada \n
        if (subtitle == 'Social'):
            socmed_containers = bio_containers[j].find_all('li')
            for k in range(0, len(socmed_containers)):
                social.append((socmed_containers[k].a['href']))
        else:
            bio.append((subtitle, content))
        
        
    athlete.append((ath_url, name, surname, nationality, discipline, birth_date, birth_city, birth_country, age, height_cm, height, weight_kg, weight_lbs, int(gold), int(silver), int(bronze), bio, social, bio_url))
    #height_cm, weight_kg, dan weight_lbs belum jadi int karena bisa berisikan '-' #kasus #351
    #age belum jadi int karena berisikan '\n' #kasus #768
# Out:
# Request:222; Frequency: 0.14390825619585307 requests/s

# %%
athlete_wu_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'social', 'bio_url'])
athlete_wu_df.to_csv('ag2018_athletes_wu.csv', index = False)

# %% [markdown]
# # Country Athletes

# %%
country_ath_url = 'https://en.asiangames2018.id/athletes/countries/'

# Make a list of countries' code
response = get(country_ath_url)
soup = BeautifulSoup(response.text, 'html.parser')

country_containers = soup.find_all('li', class_ = 'or-countries-list__item')

country_ = []
for country in country_containers:
    noc_name = country.find('div', class_ = 'or-countries-list__name').text
    noc_ath_no = country.find('div', class_ = 'or-countries-list__number-athletes').text
    noc_ath_no = noc_ath_no[0:noc_ath_no.find(" ")]
    noc_ath_url = 'https://en.asiangames2018.id' + country.find('a')['href']
    noc_code = country.find('a')['href'][18:21]
    page_no = math.ceil(int(noc_ath_no)/12)
    country_.append((noc_ath_url, noc_code, noc_name, noc_ath_no, page_no))
    
country_ath_df = pd.DataFrame(country_, columns = ['noc_url', 'noc_code', 'country_name', 'no_athlete_noc', 'page_no'])
country_ath_df.to_csv('ag2018_country_athlete_summary.csv', index = False)

# %%
country_ath_df
# Out:
#                                               noc_url noc_code  \
# 0   https://en.asiangames2018.id/athletes/country/...      AFG
# 1   https://en.asiangames2018.id/athletes/country/...      BRN
# 2   https://en.asiangames2018.id/athletes/country/...      BAN
# 3   https://en.asiangames2018.id/athletes/country/...      BHU
# 4   https://en.asiangames2018.id/athletes/country/...      BRU
# 5   https://en.asiangames2018.id/athletes/country/...      CAM
# 6   https://en.asiangames2018.id/athletes/country/...      CHN
# 7   https://en.asiangames2018.id/athletes/country/...      HKG
# 8   https://en.asiangames2018.id/athletes/country/...      IND
# 9   https://en.asiangames2018.id/athletes/country/...      IRI
# 10  https://en.asiangames2018.id/athletes/country/...      IRQ
# 11  https://en.asiangames2018.id/athletes/country/...      JPN
# 12  https://en.asiangames2018.id/athletes/country/...      JOR
# 13  https://en.asiangames2018.id/athletes/country/...      KAZ
# 14  https://en.asiangames2018.id/athletes/country/...      COR
# 15  https://en.asiangames2018.id/athletes/country/...      KOR
# 16  https://en.asiangames2018.id/athletes/country/...      KUW
# 17  https://en.asiangames2018.id/athletes/country/...      KSA
# 18  https://en.asiangames2018.id/athletes/country/...      KGZ
# 19  https://en.asiangames2018.id/athletes/country/...      LAO
# 20  https://en.asiangames2018.id/athletes/country/...      LBN
# 21  https://en.asiangames2018.id/athletes/country/...      MAC
# 22  https://en.asiangames2018.id/athletes/country/...      MAS
# 23  https://en.asiangames2018.id/athletes/country/...      MDV
# 24  https://en.asiangames2018.id/athletes/country/...      MGL
# 25  https://en.asiangames2018.id/athletes/country/...      MYA
# 26  https://en.asiangames2018.id/athletes/country/...      NEP
# 27  https://en.asiangames2018.id/athletes/country/...      OMA
# 28  https://en.asiangames2018.id/athletes/country/...      PAK
# 29  https://en.asiangames2018.id/athletes/country/...      PLE
# 30  https://en.asiangames2018.id/athletes/country/...      PHI
# 31  https://en.asiangames2018.id/athletes/country/...      PRK
# 32  https://en.asiangames2018.id/athletes/country/...      QAT
# 33  https://en.asiangames2018.id/athletes/country/...      SGP
# 34  https://en.asiangames2018.id/athletes/country/...      SRI
# 35  https://en.asiangames2018.id/athletes/country/...      SYR
# 36  https://en.asiangames2018.id/athletes/country/...      THA
# 37  https://en.asiangames2018.id/athletes/country/...      TJK
# 38  https://en.asiangames2018.id/athletes/country/...      TKM
# 39  https://en.asiangames2018.id/athletes/country/...      TLS
# 40  https://en.asiangames2018.id/athletes/country/...      TPE
# 41  https://en.asiangames2018.id/athletes/country/...      UAE
# 42  https://en.asiangames2018.id/athletes/country/...      UZB
# 43  https://en.asiangames2018.id/athletes/country/...      VIE
# 44  https://en.asiangames2018.id/athletes/country/...      YEM
# 45  https://en.asiangames2018.id/athletes/country/...      INA
#
#                country_name no_athlete_noc  page_no
# 0               Afghanistan             88        8
# 1                   Bahrain            109       10
# 2                Bangladesh            128       11
# 3                    Bhutan             24        2
# 4         Brunei Darussalam             15        2
# 5                  Cambodia             45        4
# 6                     China            893       75
# 7          Hong Kong, China            599       50
# 8                     India            711       60
# 9                   IR Iran            394       33
# 10                     Iraq             61        6
# 11                    Japan            800       67
# 12                   Jordan             54        5
# 13               Kazakhstan            522       44
# 14                    Korea             60        5
# 15        Republic of Korea            806       68
# 16                   Kuwait             43        4
# 17  Kingdom of Saudi Arabia            180       15
# 18               Kyrgyzstan            221       19
# 19                  Lao PDR            139       12
# 20                  Lebanon             30        3
# 21             Macau, China            110       10
# 22                 Malaysia            450       38
# 23                 Maldives            152       13
# 24                 Mongolia            328       28
# 25                  Myanmar            139       12
# 26                    Nepal            194       17
# 27                     Oman             75        7
# 28                 Pakistan            312       26
# 29                Palestine             89        8
# 30              Philippines            322       27
# 31                DPR Korea            167       14
# 32                    Qatar            236       20
# 33                Singapore            267       23
# 34                Sri Lanka            201       17
# 35                    Syria             75        7
# 36                 Thailand            827       69
# 37               Tajikistan            112       10
# 38             Turkmenistan             74        7
# 39              Timor Leste             69        6
# 40           Chinese Taipei            564       47
# 41     United Arab Emirates            148       13
# 42               Uzbekistan            337       29
# 43                  Vietnam            363       31
# 44                    Yemen             32        3
# 45                Indonesia            968       81

# %% [markdown]
# ### all Indonesian athletes

# %%
start_time = time.time()
requests = 0

# %%
pages_ina = [str(i) for i in range(1, country_ath_df['page_no'][45] + 1)]

# %%
ina_ath = []
for page in pages_ina:
    ina_ath_url = 'https://en.asiangames2018.id/athletes/country/INA/page/' + page + '/'
    
    response = get(ina_ath_url)

    sleep(randint(8,15))
    
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
    
    athlete_soup = BeautifulSoup(response.text, 'html.parser')
    
    athletes = athlete_soup.find_all('li', class_ = 'or-athletes__item')
    
    for athlete in athletes:
        fname = athlete.find('div', class_ = 'or-card-athlete__name')['title'] #fname = surname + name
        name = athlete.find('div', class_ = 'or-card-athlete__passport-name').text
        surname = athlete.find('div', class_ = 'or-card-athlete__passport-surname').text
        country = athlete.find('img', class_ = 'or-card-athlete__country-flag')['title']
        noc_code = athlete.find('div', class_ = 'or-card-athlete__country-code').text
        discipline = athlete.find('div', class_ = 'or-card-athlete__discipline').text
        url = 'https://en.asiangames2018.id' + athlete.find('a', class_ = 'or-athletes__link')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya

        ina_ath.append((url, fname, name, surname, country, noc_code, discipline))
        
ina_ath_df = pd.DataFrame(ina_ath, columns =['url', 'fullname', 'name', 'surname', 'country', 'noc_code', 'discipline'])
ina_ath_df.to_csv('ag2018_ina_athletes.csv', index=False)
# Out:
# Request:81; Frequency: 0.038484302622323434 requests/s

# %%
athlete = []
start_time = time.time()
requests = 0

for i in range(0, int(country_ath_df['no_athlete_noc'][45]) + 2): #ada tambahan 2 atlet daripada data yang ada (sepertinya karena ada double)
    bio = []
    social = []
    
    ath_url = ina_ath_df['url'][i]
    ath_response = get(ath_url)
    ath_soup = BeautifulSoup(ath_response.text, 'html.parser')

    
    sleep(randint(1,4))
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)    
    
    name = ath_soup.find('span', class_ = 'or-athlete-profile__name--name').text
    surname = ath_soup.find('span', class_ = 'or-athlete-profile__name--surname').text
    nationality = ath_soup.find('span', class_ = 'or-athlete-profile__nationality--noc').text
    discipline = ath_soup.find('div', class_ = 'or-athlete-profile__discipline').text
    birth_date = ath_soup.find('span', class_ = 'or-athlete__birth--date').text
    birth_city = ath_soup.find('span', class_ = 'or-athlete__birth--city').text
    
    if ath_soup.find('span', class_ = 'or-athlete__birth--country') is not None:
        birth_country = ath_soup.find('span', class_ = 'or-athlete__birth--country').text
    else: birth_country = ''
    
    age = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[0].text
    height = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[2].text
    weight = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[3].text
    
    birth_country = birth_country[1:-1]
    age = age.replace(' ', '')
    age = age.replace('\r\n', '')
    height = height.replace(' ', '')
    height = height.replace('\r', '')
    height = height.replace('\n', '')
    if (height == '-/-'):
        height_cm = ''
        height = ''
    else:
        height_cm = height[0:height.find("CM")] #kalau height = '-/...' atau height.find("CM") == -1, maka akan menyimpan nilai '-/'
        height = height[len(height_cm) + 3:] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    weight = weight.replace(' ', '')
    weight = weight.replace('\r', '')
    weight = weight.replace('\n', '')
    if (weight == '-/-'):
        weight_kg = ''
        weight_lbs = ''
    else:
        weight_kg = weight[0:weight.find("kg")] #kalau weight = '-/...' atau weight.find("kg") == -1, maka akan menyimpan nilai '-/'
        weight_lbs = weight[weight.find("kg") + 3:weight.find("lbs")] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    
    
    src_containers = ath_soup.find_all('orp')
    
    medal_containers = src_containers[0]
    ath_medal_url = medal_containers['src']


    sleep(randint(1,2))

    
    response = get(ath_medal_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup.find_all('td', class_ = 'or-table-medals__b--medal') != []:
        gold = soup.find_all('td', class_ = 'or-table-medals__b--medal')[0].text
        silver = soup.find_all('td', class_ = 'or-table-medals__b--medal')[1].text
        bronze = soup.find_all('td', class_ = 'or-table-medals__b--medal')[2].text
    else:
        gold = 0
        silver = 0
        bronze = 0
    
    bio_containers = src_containers[1]
    bio_url = bio_containers['src']
    bio_response = get(bio_url)
    bio_soup = BeautifulSoup(bio_response.text, 'html.parser')


    sleep(randint(1,2))

    
    bio_containers = bio_soup.find_all('div', class_ ='or-article__part markdown')
    
    for j in range(0, len(bio_containers)):
        subtitle = bio_containers[j].h2.text #Perlu lebih dirapikan di bagian ini
        content = bio_containers[j].p.text #ada b, ada br, ada \n
        if (subtitle == 'Social'):
            socmed_containers = bio_containers[j].find_all('li')
            for k in range(0, len(socmed_containers)):
                social.append((socmed_containers[k].a['href']))
        else:
            bio.append((subtitle, content))
        
        
    athlete.append((ath_url, name, surname, nationality, discipline, birth_date, birth_city, birth_country, age, height_cm, height, weight_kg, weight_lbs, int(gold), int(silver), int(bronze), bio, social, bio_url))
    #height_cm, weight_kg, dan weight_lbs belum jadi int karena bisa berisikan '-' #kasus #351
    #age belum jadi int karena berisikan '\n' #kasus #768
# Out:
# Request:2; Frequency: 0.1766102453129674 requests/s

# %%
athlete_ina_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'social', 'bio_url'])
athlete_ina_df.to_csv('ag2018_athletes_ina.csv', index = False)

# %%
country_ath_df = pd.read_csv('ag2018_country_athlete_summary.csv')

# %%
for j in range(0, len(country_ath_df)):
    pages_noc = [str(i) for i in range(1, int(country_ath_df['page_no'][j]) + 1)]
    
    start_time = time.time()
    requests = 0
    
    noc_ath = []
    
    for page in pages_noc:
        noc_ath_url = 'https://en.asiangames2018.id/athletes/country/' + country_ath_df['noc_code'][j] + '/page/' + page + '/'
    
        response = get(noc_ath_url)

        sleep(randint(8,15))
    
        requests += 1
        elapsed_time = time.time() - start_time
        print('Request: {}.{}; Frequency: {} requests/s'.format(j, requests, requests/elapsed_time))
        clear_output(wait = True)
    
        athlete_soup = BeautifulSoup(response.text, 'html.parser')
    
        athletes = athlete_soup.find_all('li', class_ = 'or-athletes__item')
    
        for athlete in athletes:
            fname = athlete.find('div', class_ = 'or-card-athlete__name')['title'] #fname = surname + name
            name = athlete.find('div', class_ = 'or-card-athlete__passport-name').text
            surname = athlete.find('div', class_ = 'or-card-athlete__passport-surname').text
            country = athlete.find('img', class_ = 'or-card-athlete__country-flag')['title']
            noc_code = athlete.find('div', class_ = 'or-card-athlete__country-code').text
            discipline = athlete.find('div', class_ = 'or-card-athlete__discipline').text
            url = 'https://en.asiangames2018.id' + athlete.find('a', class_ = 'or-athletes__link')['href'] # Perlu ditambahkan 'https://en.asiangames2018.id' di depannya

            noc_ath.append((url, fname, name, surname, country, noc_code, discipline))
        
    noc_ath_df = pd.DataFrame(noc_ath, columns =['url', 'fullname', 'name', 'surname', 'country', 'noc_code', 'discipline'])
    name_file = 'AG2018_country_athletes\\ag2018_' + str(int(j) + 1) + '.' + country_ath_df['noc_code'][j].lower() + '_athletes.csv'
    noc_ath_df.to_csv(name_file, index=False)
# Out:
# Request: 45.81; Frequency: 0.06865254259986078 requests/s

# %%
noc_ath
# Out:
# [('https://en.asiangames2018.id/athletes/athlete/ABESING-WIJESEKARA-Lakmal-3022422/',
#   'ABESING WIJESEKARA Lakmal',
#   'Lakmal',
#   'Abesing Wijesekara',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/ABEYSINGHE-Kyle-Charles-3017117/',
#   'ABEYSINGHE Kyle Charles',
#   'KYLE CHARLES',
#   'ABEYSINGHE',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/ABEYSINGHE-Matthew-Duncan-3018297/',
#   'ABEYSINGHE Matthew Duncan',
#   'MATTHEW DUNCAN',
#   'ABEYSINGHE',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/ABEYSOORIYA-Supun-Chinthaka-3013691/',
#   'ABEYSOORIYA Supun Chinthaka',
#   'SUPUN CHINTHAKA',
#   'ABEYSOORIYA',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/ALAHAKOON-PATHIRANALAGE-Madurika-H-3013439/',
#   'ALAHAKOON PATHIRANALAGE Madurika H.',
#   'MADURIKA HANSAMALI',
#   'ALAHAKOON PATHIRANALAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/ANDAHENDIGE-Shamil-Malinda-Silva-3021791/',
#   'ANDAHENDIGE Shamil Malinda Silva',
#   'Shamil Malinda Silva',
#   'Andahendige',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/ARACHCHI-APPUHAMILAGE-DON-D-K-3025254/',
#   'ARACHCHI APPUHAMILAGE DON D. K.',
#   'DILSHAN KAVIN',
#   'ARACHCHI APPUHAMILAGE DON',
#   'Sri Lanka',
#   'SRI',
#   'Artistic Gymnastics'),
#  ('https://en.asiangames2018.id/athletes/athlete/ARTIGALA-ABERATHNA-Gayanthika-Thushari-3018526/',
#   'ARTIGALA ABERATHNA Gayanthika Thushari',
#   'Gayanthika Thushari',
#   'Artigala Aberathna',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/ASIRI-Sandaruwan-3013456/',
#   'ASIRI Sandaruwan',
#   'sandaruwan',
#   'asiri',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/ASLAM-Saja-3012652/',
#   'ASLAM Saja',
#   'saja',
#   'aslam',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/BADDE-GEDARA-Sanjeewa-Udayasiri-J-3013038/',
#   'BADDE GEDARA Sanjeewa Udayasiri J.',
#   'SANJEEWA UDAYASIRI JAYARA',
#   'BADDE GEDARA',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/BALAWARDHANA-Pethum-Nuwan-3018919/',
#   'BALAWARDHANA Pethum Nuwan',
#   'PETHUM NUWAN',
#   'BALAWARDHANA',
#   'Sri Lanka',
#   'SRI',
#   'Wushu'),
#  ('https://en.asiangames2018.id/athletes/athlete/BANDARA-Meethalawe-Vidanalage-Ish-3013077/',
#   'BANDARA Meethalawe Vidanalage Ish',
#   'MEETHALAWE VIDANALAGE ISHAN RA',
#   'BANDARA',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/BENTHU-HEWAGE-Wasantha-Lakmal-3021794/',
#   'BENTHU HEWAGE Wasantha Lakmal',
#   'Wasantha Lakmal',
#   'Benthu Hewage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/BODIYABADU-WIJESINGHEGE-T-S-R-3024294/',
#   'BODIYABADU WIJESINGHEGE T. S. R.',
#   'THARANGA SAMPATH RUPASINGHE',
#   'BODIYABADU WIJESINGHEGE',
#   'Sri Lanka',
#   'SRI',
#   'Rowing'),
#  ('https://en.asiangames2018.id/athletes/athlete/BOGAHALANDA-Gnanasagari-Gunasingha-3021780/',
#   'BOGAHALANDA Gnanasagari Gunasingha',
#   'GNANASAGARI GUNASINGHA',
#   'BOGAHALANDA',
#   'Sri Lanka',
#   'SRI',
#   'Beach Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/BOTHALE-APPUHAMILAGE-DON-R-S-N-3029808/',
#   'BOTHALE APPUHAMILAGE DON R. S. N.',
#   'Ravidu Seran Nimanka',
#   'Bothale Appuhamilage Don',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/CHAKRAWARTHIGE-Rehan-Rumesh-Silva-3013230/',
#   'CHAKRAWARTHIGE Rehan Rumesh Silva',
#   'Rehan Rumesh Silva',
#   'Chakrawarthige',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/CHANDRADAS-Dansha-Dayan-3013498/',
#   'CHANDRADAS Dansha Dayan',
#   'Dansha Dayan',
#   'Chandradas',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/CHARLES-FERNANDO-Divoshan-3018883/',
#   'CHARLES FERNANDO Divoshan',
#   'Divoshan',
#   'Charles Fernando',
#   'Sri Lanka',
#   'SRI',
#   'Wrestling'),
#  ('https://en.asiangames2018.id/athletes/athlete/DAPANA-DURAGE-Imesha-Thathsarani-3027876/',
#   'DAPANA DURAGE Imesha Thathsarani',
#   'Imesha Thathsarani',
#   'Dapana Durage',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/de-SILVA-Kulappu-Thantrige-Cherant-3018298/',
#   'de SILVA Kulappu Thantrige Cherant',
#   'KULAPPU THANTRIGE CHERANTHA GI',
#   'DE SILVA',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/de-SILVA-Mahamadaachchi-Sajeev-3012472/',
#   'de SILVA Mahamadaachchi Sajeev',
#   'MAHAMADAACHCHI SAJEEV',
#   'DE SILVA',
#   'Sri Lanka',
#   'SRI',
#   'Archery'),
#  ('https://en.asiangames2018.id/athletes/athlete/de-SILVA-Sachin-9954202/',
#   'de SILVA Sachin',
#   'SACHIN',
#   'DE SILVA',
#   'Sri Lanka',
#   'SRI',
#   'Golf'),
#  ('https://en.asiangames2018.id/athletes/athlete/de-SILVA-Yasitha-Rangana-3022292/',
#   'de SILVA Yasitha Rangana',
#   'YASITHA RANGANA',
#   'DE SILVA',
#   'Sri Lanka',
#   'SRI',
#   'Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/de-SOYSA-Joseph-9954203/',
#   'de SOYSA Joseph',
#   'JOSEPH',
#   'DE SOYSA',
#   'Sri Lanka',
#   'SRI',
#   'Golf'),
#  ('https://en.asiangames2018.id/athletes/athlete/DEWA-Lakruwan-3018908/',
#   'DEWA Lakruwan',
#   'Lakruwan',
#   'Dewa',
#   'Sri Lanka',
#   'SRI',
#   'Triathlon'),
#  ('https://en.asiangames2018.id/athletes/athlete/DHARMARATHNE-Meegahamulla-Gedara-H-3029805/',
#   'DHARMARATHNE Meegahamulla Gedara H.',
#   'Meegahamulla Gedara Harindra P',
#   'Dharmarathne',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/DIAS-Sachin-3018664/',
#   'DIAS Sachin',
#   'SACHIN',
#   'DIAS',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/DILAN-Sanjaya-3012624/',
#   'DILAN Sanjaya',
#   'sanjaya',
#   'Dilan',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/DISSANAYAKE-John-Tivanka-Sharmal-3022299/',
#   'DISSANAYAKE John Tivanka Sharmal',
#   'JOHN TIVANKA SHARMAL',
#   'DISSANAYAKE',
#   'Sri Lanka',
#   'SRI',
#   'Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/DISSANAYAKE-MUDIYANSELAGE-I-C-D-3018865/',
#   'DISSANAYAKE MUDIYANSELAGE I. C. D.',
#   'INDIKA CHATHURANGA DISSAN',
#   'DISSANAYAKE MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Weightlifting'),
#  ('https://en.asiangames2018.id/athletes/athlete/DOMBAGODA-LIYANAGE-Chamika-Yasas-3014069/',
#   'DOMBAGODA LIYANAGE Chamika Yasas',
#   'CHAMIKA YASAS',
#   'DOMBAGODA LIYANAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/DON-ABRAHAM-Dinesh-Maduranga-W-3029815/',
#   'DON ABRAHAM Dinesh Maduranga W.',
#   'Dinesh Maduranga Wijesinghe',
#   'Don Abraham',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/DON-PAULU-BADALGE-Dinusha-Kumari-3015398/',
#   'DON PAULU BADALGE Dinusha Kumari',
#   'DINUSHA KUMARI',
#   'DON PAULU BADALGE',
#   'Sri Lanka',
#   'SRI',
#   'Karate'),
#  ('https://en.asiangames2018.id/athletes/athlete/THILANKA-3018863/',
#   'THILANKA',
#   'THILANKA VIRAJ KUMARA PAL',
#   'DONKAROLISLAGE',
#   'Sri Lanka',
#   'SRI',
#   'Weightlifting'),
#  ('https://en.asiangames2018.id/athletes/athlete/DORANEGALA-RANASINGHE-MUD-I-K-J-3029816/',
#   'DORANEGALA RANASINGHE MUD I. K. J.',
#   'Ishanka Kumara Jayasundara',
#   'Doranegala Ranasinghe Mudiyans',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/EDIRISINGHAGE-Nimashi-Kokila-E-3013512/',
#   'EDIRISINGHAGE Nimashi Kokila E.',
#   'NIMASHI KOKILA EDIRISINGH',
#   'EDIRISINGHAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/EGODAHA-WALAWWE-Upamalika-R-3018540/',
#   'EGODAHA WALAWWE Upamalika R.',
#   'UPAMALIKA RATHNAKUMARI',
#   'EGODAHA WALAWWE',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/EKANAYAKE-Herath-Mudiyanselage-This-3027875/',
#   'EKANAYAKE Herath Mudiyanselage This',
#   'HERATH MUDIYANSELAGE THISARAMA',
#   'EKANAYAKE',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/ENGURUWATHTHAGE-Shehan-Vimukthi-Sag-3021797/',
#   'ENGURUWATHTHAGE Shehan Vimukthi Sag',
#   'Shehan Vimukthi Sagara',
#   'Enguruwaththage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/FERNANDO-Sinna-3030562/',
#   'FERNANDO Sinna',
#   'Sinna',
#   'Fernando',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/FERNANDO-Siyabalapitiyage-Blesh-di-3013571/',
#   'FERNANDO Siyabalapitiyage Blesh di',
#   'SIYABALAPITIYAGE BLESH DI',
#   'FERNANDO',
#   'Sri Lanka',
#   'SRI',
#   'Taekwondo'),
#  ('https://en.asiangames2018.id/athletes/athlete/FERNANDO-W-Weerakonda-Arachchige-P-3029810/',
#   'FERNANDO W Weerakonda Arachchige P',
#   'W Weerakonda Arachchige Pramud',
#   'Fernando',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/FERNANDO-Wickramaratna-Widanage-Ru-3025257/',
#   'FERNANDO Wickramaratna Widanage Ru',
#   'WICKRAMARATNA WIDANAGE RUCHIRA',
#   'FERNANDO',
#   'Sri Lanka',
#   'SRI',
#   'Artistic Gymnastics'),
#  ('https://en.asiangames2018.id/athletes/athlete/GALBOKKA-HEWAGE-Amila-Pushpa-Kumara-3014036/',
#   'GALBOKKA HEWAGE Amila Pushpa Kumara',
#   'AMILA PUSHPA KUMARA',
#   'GALBOKKA HEWAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/GANGODA-GAMAGE-Sahan-Avishka-D-G-3013933/',
#   'GANGODA GAMAGE Sahan Avishka D. G.',
#   'SAHAN AVISHKA DIAS GUNASE',
#   'GANGODA GAMAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/GEORGE-PATRICK-Sisira-Kumara-9954201/',
#   'GEORGE PATRICK Sisira Kumara',
#   'SISIRA KUMARA',
#   'GEORGE PATRICK',
#   'Sri Lanka',
#   'SRI',
#   'Golf'),
#  ('https://en.asiangames2018.id/athletes/athlete/GOMAS-Bomiriyage-Dinusha-Hansan-3018867/',
#   'GOMAS Bomiriyage Dinusha Hansan',
#   'BOMIRIYAGE DINUSHA HANSAN',
#   'GOMAS',
#   'Sri Lanka',
#   'SRI',
#   'Weightlifting'),
#  ('https://en.asiangames2018.id/athletes/athlete/GONARA-GAMAGE-Lasindu-Methmal-Wasan-3021787/',
#   'GONARA GAMAGE Lasindu Methmal Wasan',
#   'Lasindu Methmal Wasanthapriya',
#   'Gonara Gamage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/GOONETHILLEKA-Buwaneka-3018659/',
#   'GOONETHILLEKA Buwaneka',
#   'BUWANEKA',
#   'GOONETHILLEKA',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/GUNARATHNA-MUDIYANSELAGE-Chamara-Mi-3022419/',
#   'GUNARATHNA MUDIYANSELAGE Chamara Mi',
#   'Chamara Mihiran',
#   'Gunarathna Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/GUNASIRI-Wadumesthrige-Subas-Isara-3013893/',
#   'GUNASIRI Wadumesthrige Subas Isara',
#   'WADUMESTHRIGE SUBAS ISARA',
#   'GUNASIRI',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/GUNAWARDANA-Tharanga-3030557/',
#   'GUNAWARDANA Tharanga',
#   'Tharanga',
#   'Gunawardana',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/GUNAWIJEYA-Solange-Kristina-3027874/',
#   'GUNAWIJEYA Solange Kristina',
#   'SOLANGE KRISTINA',
#   'GUNAWIJEYA',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/HAPUARACHCHIGE-DON-Charith-K-H-3013020/',
#   'HAPUARACHCHIGE DON Charith K. H.',
#   'CHARITH KRISHNA HAPUARACH',
#   'HAPUARACHCHIGE DON',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/HEHATHPURAGE-Deepthi-Romesh-Ranawak-3021785/',
#   'HEHATHPURAGE Deepthi Romesh Ranawak',
#   'Deepthi Romesh Ranawaka',
#   'Hehathpurage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/HENA-KANKANAMGE-Naveen-Levanjith-3013169/',
#   'HENA KANKANAMGE Naveen Levanjith',
#   'NAVEEN LEVANJITH',
#   'HENA KANKANAMGE',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/HENDENIYA-MUDIYANSELAGE-P-K-H-3029803/',
#   'HENDENIYA MUDIYANSELAGE P. K. H.',
#   'Pushpa Kumara Hendeniya',
#   'Hendeniya Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/HENDENIYA-MUDIYANSELAGE-T-K-H-3029804/',
#   'HENDENIYA MUDIYANSELAGE T. K. H.',
#   'Tharindu Kumara Hendeniya',
#   'Hendeniya Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/HERATH-EKANAYAKA-MUDIYANSELAGE-IDAME-GEDRA-Indunil-3018448/',
#   'HERATH EKANAYAKA MUDIYANSELAGE IDAME GEDRA Indunil',
#   'Indunil Madushan Herath',
#   'Herath Ekanayaka Mudiyans',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/HERATH-MUDIYANSELAGE-Dilip-Ruwan-3018446/',
#   'HERATH MUDIYANSELAGE Dilip Ruwan',
#   'Dilip Ruwan',
#   'Herath Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/HERATH-MUDIYANSELAGE-Sugath-A-S-3024323/',
#   'HERATH MUDIYANSELAGE Sugath A. S.',
#   'SUGATH AMILA SENARATHNE',
#   'HERATH MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Rowing'),
#  ('https://en.asiangames2018.id/athletes/athlete/HERATHPURA-DEWAGE-Kumudu-Kalpani-W-3013625/',
#   'HERATHPURA DEWAGE Kumudu Kalpani W.',
#   'KUMUDU KALPANI WIJERATHNA',
#   'HERATHPURA DEWAGE',
#   'Sri Lanka',
#   'SRI',
#   'Taekwondo'),
#  ('https://en.asiangames2018.id/athletes/athlete/HETTI-ARACHCHIGE-Aruna-Shantha-3014126/',
#   'HETTI ARACHCHIGE Aruna Shantha',
#   'ARUNA SHANTHA',
#   'HETTI ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/HEWA-KUMARAGE-Kalinga-Kumarage-3018453/',
#   'HEWA KUMARAGE Kalinga Kumarage',
#   'Kalinga Kumarage',
#   'Hewa Kumarage',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/HEWA-NALAGAMAGE-Indika-Damayanthi-3013453/',
#   'HEWA NALAGAMAGE Indika Damayanthi',
#   'INDIKA DAMAYANTHI',
#   'HEWA NALAGAMAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/HEWAINGE-Sampath-Ruwan-Kumara-3013981/',
#   'HEWAINGE Sampath Ruwan Kumara',
#   'SAMPATH RUWAN KUMARA',
#   'HEWAINGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/IGNESIYASGE-Asanka-Lakmal-Peiris-3013983/',
#   'IGNESIYASGE Asanka Lakmal Peiris',
#   'ASANKA LAKMAL PEIRIS',
#   'IGNESIYASGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/ISHARA-Sampath-3013412/',
#   'ISHARA Sampath',
#   'sampath',
#   'Ishara',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/ISSADEEN-Fathoum-3018769/',
#   'ISSADEEN Fathoum',
#   'FATHOUM',
#   'ISSADEEN',
#   'Sri Lanka',
#   'SRI',
#   'Squash'),
#  ('https://en.asiangames2018.id/athletes/athlete/JAHINGE-Nisansala-Sandamali-3013643/',
#   'JAHINGE Nisansala Sandamali',
#   'NISANSALA SANDAMALI',
#   'JAHINGE',
#   'Sri Lanka',
#   'SRI',
#   'Taekwondo'),
#  ('https://en.asiangames2018.id/athletes/athlete/JAYAKODY-ARACHCHIGE-Kavindu-L-J-3015348/',
#   'JAYAKODY ARACHCHIGE Kavindu L. J.',
#   'KAVINDU LAKSHITHA JAYAKODY',
#   'JAYAKODY ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Karate'),
#  ('https://en.asiangames2018.id/athletes/athlete/JAYASINHA-ARACHCHIGHE-DON-Sasika-D-3013886/',
#   'JAYASINHA ARACHCHIGHE DON Sasika D.',
#   'SASIKA DULSHAN',
#   'JAYASINHA ARACHCHIGHE DON',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/JOSEPH-Kevin-Dixon-3013109/',
#   'JOSEPH Kevin Dixon',
#   'KEVIN DIXON',
#   'JOSEPH',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/KANKANI-ACHCHI-KANKANAMAL-I-T-J-3021778/',
#   'KANKANI ACHCHI KANKANAMAL I. T. J.',
#   'INDIKA TIRON JAYATHILAKA',
#   'KANKANI ACHCHI KANKANAMALAGE',
#   'Sri Lanka',
#   'SRI',
#   'Beach Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/KANKANI-ARACHCHIGE-Thisara-D-R-3013639/',
#   'KANKANI ARACHCHIGE Thisara D. R.',
#   'THISARA DHARMAPRIYA RANAT',
#   'KANKANI ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Taekwondo'),
#  ('https://en.asiangames2018.id/athletes/athlete/KAPUGEEKIYANA-Hansani-Piumila-3021716/',
#   'KAPUGEEKIYANA Hansani Piumila',
#   'HANSANI PIUMILA',
#   'KAPUGEEKIYANA',
#   'Sri Lanka',
#   'SRI',
#   'Table Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/KARUNAMUNIGE-Nalantha-Demian-de-S-3029812/',
#   'KARUNAMUNIGE Nalantha Demian de S.',
#   'Nalantha Demian de Silva',
#   'Karunamunige',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/KARUNARATHNE-Kankani-G-C-3013969/',
#   'KARUNARATHNE Kankani G. C.',
#   'KANKANI GAMARALALAGE CHIR',
#   'KARUNARATHNE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/KARUNARATNA-Dinuka-3030239/',
#   'KARUNARATNA Dinuka',
#   'DINUKA',
#   'KARUNARATNA',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/KARUNARATNE-Niluka-3018661/',
#   'KARUNARATNE Niluka',
#   'NILUKA',
#   'KARUNARATNE',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/KASTHURI-MUDALI-Naween-Anuradha-3013698/',
#   'KASTHURI MUDALI Naween Anuradha',
#   'NAWEEN ANURADHA',
#   'KASTHURI MUDALI',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/KASTURI-ARACHCHIGE-Keshani-H-K-A-3013112/',
#   'KASTURI ARACHCHIGE Keshani H. K. A.',
#   'KESHANI HANSIKA KASTURI ARACHC',
#   'KASTURI ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/KAVIDI-Sirimannage-3018669/',
#   'KAVIDI Sirimannage',
#   'SIRIMANNAGE',
#   'KAVIDI',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/KODITHUWAKKU-ARACHCHILAGE-Anusha-D-3013107/',
#   'KODITHUWAKKU ARACHCHILAGE Anusha D.',
#   'ANUSHA DILRUKSHI',
#   'KODITHUWAKKU ARACHCHILAGE',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/KORALALAGE-DONA-Samithri-M-P-3013235/',
#   'KORALALAGE DONA Samithri M. P.',
#   'Samithri Maleesha Perera',
#   'Koralalage Dona',
#   'Sri Lanka',
#   'SRI',
#   'Roller Skate'),
#  ('https://en.asiangames2018.id/athletes/athlete/KULATHUNGA-MUDIYANSELAGE-R-D-K-3029806/',
#   'KULATHUNGA MUDIYANSELAGE R. D. K.',
#   'Rajitha Dilan Kulathunga',
#   'Kulathunga Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/KURERA-Thanipperuge-Marian-Anjal-3022396/',
#   'KURERA Thanipperuge Marian Anjal',
#   'THANIPPERUGE MARIAN ANJAL',
#   'KURERA',
#   'Sri Lanka',
#   'SRI',
#   'Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/KURUPPU-ARACHCHIGE-Sandun-M-3013957/',
#   'KURUPPU ARACHCHIGE Sandun M.',
#   'SANDUN MADUSHANKA',
#   'KURUPPU ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/LAHIRU-Kuruppu-3012537/',
#   'LAHIRU Kuruppu',
#   'Kuruppu',
#   'LAHIRU',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/LAHIRU-Sampath-3012597/',
#   'LAHIRU Sampath',
#   'sampath',
#   'Lahiru',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RAVINDU-Laksiri-3018764/',
#   'RAVINDU Laksiri',
#   'Ravindu',
#   'Laksiri',
#   'Sri Lanka',
#   'SRI',
#   'Squash'),
#  ('https://en.asiangames2018.id/athletes/athlete/LANKAPURAYALAGE-Krismi-Ayoma-D-D-3013170/',
#   'LANKAPURAYALAGE Krismi Ayoma D. D.',
#   'KRISMI AYOMA DULANJANI DHARMAT',
#   'LANKAPURAYALAGE',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/LEON-THINESHKANTH-Thimothi-N-3027869/',
#   'LEON THINESHKANTH Thimothi N.',
#   'THIMOTHI NITHUSHAN',
#   'LEON THINESHKANTH',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/LIYANA-ARACHCHIGE-Dilshan-P-3014027/',
#   'LIYANA ARACHCHIGE Dilshan P.',
#   'DILSHAN PRIYADARSHANA',
#   'LIYANA ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/LIYANAGE-Chalinda-Sampath-Liyanage-3013618/',
#   'LIYANAGE Chalinda Sampath Liyanage',
#   'CHALINDA SAMPATH LIYANAGE',
#   'LIYANAGE',
#   'Sri Lanka',
#   'SRI',
#   'Taekwondo'),
#  ('https://en.asiangames2018.id/athletes/athlete/LOKUKALUGE-Akihiro-3015341/',
#   'LOKUKALUGE Akihiro',
#   'AKIHIRO',
#   'LOKUKALUGE',
#   'Sri Lanka',
#   'SRI',
#   'Karate'),
#  ('https://en.asiangames2018.id/athletes/athlete/MADURAPPERUMA-ARACHCHILAG-T-K-3013575/',
#   'MADURAPPERUMA ARACHCHILAG T. K.',
#   'THILINI KANCHANA',
#   'MADURAPPERUMA ARACHCHILAG',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/MADUSHAN-Pushpakumara-3012565/',
#   'MADUSHAN Pushpakumara',
#   'pushpakumara',
#   'madushan',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/MAHABADUGE-Chamilka-Rukshan-3029817/',
#   'MAHABADUGE Chamilka Rukshan',
#   'Chamilka Rukshan',
#   'Mahabaduge',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/MAHANTIMULLA-GAMAGE-Rashmika-K-W-3021693/',
#   'MAHANTIMULLA GAMAGE Rashmika K. W.',
#   'RASHMIKA KRISHAN WICKRAMARATHN',
#   'MAHANTIMULLA GAMAGE',
#   'Sri Lanka',
#   'SRI',
#   'Table Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/MALEGODA-GAMAGE-Sanjeewe-3029807/',
#   'MALEGODA  GAMAGE Sanjeewe',
#   'Sanjeewe',
#   'Malegoda  Gamage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/MALWATHTHE-GEDARA-Neranjan-M-G-3013115/',
#   'MALWATHTHE GEDARA Neranjan M. G.',
#   'Neranjan Madushanka Gayan Weer',
#   'Malwaththe Gedara',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANDALA-KANKANAMGE-Buddhika-C-3024290/',
#   'MANDALA KANKANAMGE Buddhika C.',
#   'BUDDHIKA CHATHURANGA',
#   'MANDALA KANKANAMGE',
#   'Sri Lanka',
#   'SRI',
#   'Rowing'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANIKDURA-Chandana-5255006/',
#   'MANIKDURA Chandana',
#   'Chandana',
#   'Manikdura',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANIKDURA-GEDRA-Chandana-C-C-3029941/',
#   'MANIKDURA GEDRA Chandana C. C.',
#   'CHANDANA CHATHURANGA CHANDRASE',
#   'MANIKDURA GEDRA',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANIKKAVALAGE-Gayan-Madushanka-Prem-3021784/',
#   'MANIKKAVALAGE Gayan Madushanka Prem',
#   'Gayan Madushanka Premarathna',
#   'Manikkavalage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANNA-UTHUM-MUDIYANSELAGE-L-S-M-3013970/',
#   'MANNA UTHUM MUDIYANSELAGE L. S. M.',
#   'LASANTHA SANJEEWA MANNA U',
#   'MANNA UTHUM MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/MANNIKKUBADU-Ishara-Madurangi-D-3021715/',
#   'MANNIKKUBADU Ishara Madurangi D.',
#   'ISHARA MADURANGI DARSHIKA',
#   'MANNIKKUBADU',
#   'Sri Lanka',
#   'SRI',
#   'Table Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/MATUGAMA-LIYANAGE-Kaushala-P-3014022/',
#   'MATUGAMA LIYANAGE Kaushala P.',
#   'KAUSHALA PRABUDDHA',
#   'MATUGAMA LIYANAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/MEDAGEDARA-LEKAMLAGE-Asanka-P-K-3021776/',
#   'MEDAGEDARA LEKAMLAGE Asanka P. K.',
#   'Asanka Pradeep Kumara',
#   'Medagedara Lekamlage',
#   'Sri Lanka',
#   'SRI',
#   'Beach Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/MIHILIYA-Methsarani-3018768/',
#   'MIHILIYA Methsarani',
#   'METHSARANI',
#   'MIHILIYA',
#   'Sri Lanka',
#   'SRI',
#   'Squash'),
#  ('https://en.asiangames2018.id/athletes/athlete/MILIDDUWA-GAMAGE-Pawan-Samira-3027870/',
#   'MILIDDUWA GAMAGE Pawan Samira',
#   'Pawan Samira',
#   'Milidduwa Gamage',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/MILINDA-Chathuranga-3012554/',
#   'MILINDA Chathuranga',
#   'chathuranga',
#   'Milinda',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/MILLAGAHA-GEDARA-Ajith-Premakumara-3018436/',
#   'MILLAGAHA GEDARA Ajith Premakumara',
#   'Ajith Premakumara',
#   'Millagaha Gedara',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/MORSETH-Fathima-Luban-Mehthab-3027877/',
#   'MORSETH Fathima Luban Mehthab',
#   'Fathima Luban Mehthab',
#   'Morseth',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/MUKTHAR-WAKEEL-Mohomed-Shamil-3024159/',
#   'MUKTHAR WAKEEL Mohomed Shamil',
#   'MOHOMED SHAMIL',
#   'MUKTHAR WAKEEL',
#   'Sri Lanka',
#   'SRI',
#   'Squash'),
#  ('https://en.asiangames2018.id/athletes/athlete/MUKUDAM-WASAM-Tharika-Samanmali-3015338/',
#   'MUKUDAM WASAM Tharika Samanmali',
#   'THARIKA SAMANMALI',
#   'MUKUDAM WASAM',
#   'Sri Lanka',
#   'SRI',
#   'Karate'),
#  ('https://en.asiangames2018.id/athletes/athlete/MUNIPURAGE-Malith-Dinidu-Chamara-3021790/',
#   'MUNIPURAGE Malith Dinidu Chamara',
#   'Malith Dinidu Chamara',
#   'Munipurage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/MUTHUTHANTRI-Sudarshana-Sriyanga-M-3013155/',
#   'MUTHUTHANTRI Sudarshana Sriyanga M.',
#   'Sudarshana Sriyanga Mihiran',
#   'Muthuthantri',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/MUTHUWADIGE-Danushka-Dilshan-Fernan-3021796/',
#   'MUTHUWADIGE Danushka Dilshan Fernan',
#   'Danushka Dilshan Fernando',
#   'Muthuwadige',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/NANAYAKKARA-KUDACHCHIGE-B-B-P-3013396/',
#   'NANAYAKKARA KUDACHCHIGE B. B. P.',
#   'Buddima Bushma Piyarathana',
#   'Nanayakkara Kudachchige',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/NAUSHARD-ISSADEEN-Fathima-F-Z-3024171/',
#   'NAUSHARD ISSADEEN Fathima F. Z.',
#   'Zaleeha Fathoum',
#   'NAUSHARD ISSADEEN',
#   'Sri Lanka',
#   'SRI',
#   'Squash'),
#  ('https://en.asiangames2018.id/athletes/athlete/NISHANTHA-Gunawardane-3012529/',
#   'NISHANTHA Gunawardane',
#   'Gunawardane',
#   'Nishantha',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/NISSANKA-Madhuranga-Dhilina-3021222/',
#   'NISSANKA Madhuranga Dhilina',
#   'MADHURANGA DHILINA',
#   'NISSANKA',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/NUGAWELA-R-C-W-Mudiyanse-Ralahamil-3021800/',
#   'NUGAWELA R C W Mudiyanse Ralahamil',
#   'R C W MUDIYANSE RALAHAMILLAGE ',
#   'NUGAWELA',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/ONDAATJE-Anna-Marie-3018115/',
#   'ONDAATJE Anna-Marie',
#   'Anna-Marie',
#   'Ondaatje',
#   'Sri Lanka',
#   'SRI',
#   'Rhythmic Gymnastics'),
#  ('https://en.asiangames2018.id/athletes/athlete/PALLEHA-MUTURANWELLIGE-T-S-R-3013057/',
#   'PALLEHA MUTURANWELLIGE T. S. R.',
#   'THIWANKA SANDARUWAN RANASINGHE',
#   'PALLEHA MUTURANWELLIGE',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/PANADURA-ARACHCHIGE-DON-Ayesh-Dilha-3021792/',
#   'PANADURA ARACHCHIGE DON Ayesh Dilha',
#   'Ayesh Dilhan Perera',
#   'Panadura Arachchige Don',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/PANAMBARA-MUDIYANSELAGE-Pasindu-Lakshan-Kodikara-3018455/',
#   'PANAMBARA MUDIYANSELAGE Pasindu Lakshan Kodikara',
#   'Pasindu Lakshan Kodikara',
#   'Panambara Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/PANDIGE-Kasun-Chathuranga-Fernando-3021795/',
#   'PANDIGE Kasun Chathuranga Fernando',
#   'Kasun Chathuranga Fernando',
#   'Pandige',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/PANTHIE-GEDARA-Lahiru-Gihan-W-3029818/',
#   'PANTHIE GEDARA Lahiru Gihan W.',
#   'Lahiru Gihan Weerasooriya',
#   'Panthie Gedara',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/PEIRIS-Halpewaththaga-Dimuth-Aka-3018300/',
#   'PEIRIS Halpewaththaga Dimuth Aka',
#   'HALPEWATHTHAGA DIMUTH AKALANKA',
#   'PEIRIS',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/PEIRIS-Halpewaththage-Dimuth-Aka-3021804/',
#   'PEIRIS Halpewaththage Dimuth Aka',
#   'HALPEWATHTHAGE DIMUTH AKALANKA',
#   'PEIRIS',
#   'Sri Lanka',
#   'SRI',
#   'Swimming'),
#  ('https://en.asiangames2018.id/athletes/athlete/PILADUWA-MAHA-BOGAHAWATTA-Iresh-K-3013946/',
#   'PILADUWA MAHA BOGAHAWATTA Iresh K.',
#   'IRESH KOSALA',
#   'PILADUWA MAHA BOGAHAWATTA',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/PONNA-HANDI-THARIDU-Madumal-3013990/',
#   'PONNA HANDI THARIDU Madumal',
#   'MADUMAL',
#   'PONNA HANDI THARIDU',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/PONNAWILA-VIDANALAGE-DON-D-D-S-3013093/',
#   'PONNAWILA VIDANALAGE DON D. D. S.',
#   'DININDU DUSHAN SAPARAMADU',
#   'PONNAWILA VIDANALAGE DON',
#   'Sri Lanka',
#   'SRI',
#   'Boxing'),
#  ('https://en.asiangames2018.id/athletes/athlete/PREMARATHNAGE-Methusala-Thilakshini-3013561/',
#   'PREMARATHNAGE Methusala Thilakshini',
#   'METHUSALA THILAKSHINI',
#   'PREMARATHNAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RAFFAIDEEN-Thuwan-Reeza-3013212/',
#   'RAFFAIDEEN Thuwan Reeza',
#   'Thuwan Reeza',
#   'Raffaideen',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/RAJAPAKSHA-ARACHCHIGE-Damith-H-K-3028247/',
#   'RAJAPAKSHA ARACHCHIGE Damith H. K.',
#   'DAMITH HEMANTHA KUMARA',
#   'RAJAPAKSHA ARACHCHIGE',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANASINGHA-ARACHCHIGE-D-P-R-3029819/',
#   'RANASINGHA ARACHCHIGE D. P. R.',
#   'Dhammika Prabath Ranasingha',
#   'Ranasingha Arachchige',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANASINGHE-Hena-Kankanamge-Kasthuri-3013262/',
#   'RANASINGHE Hena Kankanamge Kasthuri',
#   'HENA KANKANAMGE KASTHURI',
#   'RANASINGHE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANASINGHE-Imesh-Udaya-3021692/',
#   'RANASINGHE Imesh Udaya',
#   'IMESH UDAYA',
#   'RANASINGHE',
#   'Sri Lanka',
#   'SRI',
#   'Table Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANHOTE-PEDIGE-Madushani-Chathurika-3013580/',
#   'RANHOTE PEDIGE Madushani Chathurika',
#   'MADUSHANI CHATHURIKA',
#   'RANHOTE PEDIGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANIDU-Chamara-3013328/',
#   'RANIDU Chamara',
#   'chamara',
#   'ranidu',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RANKOTHGEDARA-Anuradha-Srinath-S-3013313/',
#   'RANKOTHGEDARA Anuradha Srinath S.',
#   'Anuradha Srinath Sooriyabandar',
#   'Rankothgedara',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKA-Sameera-Sampath-3013682/',
#   'RATHNAYAKA Sameera Sampath',
#   'SAMEERA SAMPATH',
#   'RATHNAYAKA',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKA-MUDIYANSELAGE-Sasika-D-3013488/',
#   'RATHNAYAKA MUDIYANSELAGE Sasika D.',
#   'SASIKA DULANJALEE',
#   'RATHNAYAKA MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKE-Uda-Kuburalage-Nilani-3018531/',
#   'RATHNAYAKE Uda Kuburalage Nilani',
#   'Uda Kuburalage Nilani',
#   'Rathnayake',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKE-KANKANANGE-Sithumini-M-3013525/',
#   'RATHNAYAKE KANKANANGE Sithumini M.',
#   'SITHUMINI MANODANI',
#   'RATHNAYAKE KANKANANGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKE-MUDIYANSELAGE-A-S-3029820/',
#   'RATHNAYAKE MUDIYANSELAGE A. S.',
#   'Anuradha Suresh',
#   'Rathnayake Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATHNAYAKE-MUDIYANSELAGE-G-S-A-3029821/',
#   'RATHNAYAKE MUDIYANSELAGE G. S. A.',
#   'Gihan Sangeeth Amarasinghe',
#   'Rathnayake Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATNAYAKE-MUDIYANSELAGE-Rumeshika-Kumari-3018537/',
#   'RATNAYAKE MUDIYANSELAGE Rumeshika Kumari',
#   'Rumeshika Kumari Rathnaya',
#   'Ratnayake Mudiyanselage',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/RATWATTE-Ashan-Tharinda-3030240/',
#   'RATWATTE Ashan Tharinda',
#   'Ashan Tharinda',
#   'Ratwatte',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/RAVINDRAN-Anne-Stephanie-3030561/',
#   'RAVINDRAN Anne Stephanie',
#   'Anne Stephanie',
#   'Ravindran',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/REPIYALLAGE-Chamara-Nuwan-D-3018976/',
#   'REPIYALLAGE Chamara Nuwan D.',
#   '*Chamara Nuwan Dharmawardh',
#   'REPIYALLAGE',
#   'Sri Lanka',
#   'SRI',
#   'Judo'),
#  ('https://en.asiangames2018.id/athletes/athlete/SAJITH-Indrakumara-3012350/',
#   'SAJITH Indrakumara',
#   'Indrakumara',
#   'Sajith',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/SAMARAKOON-MUDIYANSELAGE-C-R-3012578/',
#   'SAMARAKOON MUDIYANSELAGE C. R.',
#   'CHAMINDA RUWAN',
#   'SAMARAKOON MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/SAMPAYA-Niyon-Tharindu-3015381/',
#   'SAMPAYA Niyon Tharindu',
#   'NIYON THARINDU',
#   'SAMPAYA',
#   'Sri Lanka',
#   'SRI',
#   'Karate'),
#  ('https://en.asiangames2018.id/athletes/athlete/SENEVIRATNE-Anika-Chloe-3022327/',
#   'SENEVIRATNE Anika Chloe',
#   'ANIKA CHLOE',
#   'SENEVIRATNE',
#   'Sri Lanka',
#   'SRI',
#   'Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/SINGHAPURAGE-Aruna-Dharshana-3018441/',
#   'SINGHAPURAGE Aruna Dharshana',
#   'Aruna Dharshana',
#   'Singhapurage',
#   'Sri Lanka',
#   'SRI',
#   'Athletics'),
#  ('https://en.asiangames2018.id/athletes/athlete/SOYSA-Edirimunige-Dasuni-Tharin-3013222/',
#   'SOYSA Edirimunige Dasuni Tharin',
#   'Edirimunige Dasuni Tharindaya',
#   'Soysa',
#   'Sri Lanka',
#   'SRI',
#   'Roller Skate'),
#  ('https://en.asiangames2018.id/athletes/athlete/SRI-WICKRAMAGE-DON-Rashmi-Taniya-Pe-3030560/',
#   'SRI WICKRAMAGE DON Rashmi Taniya Pe',
#   'Rashmi Taniya Perera',
#   'Sri Wickramage Don',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/SUBASINGHA-ARACCHILAGE-Janitha-Sura-3021788/',
#   'SUBASINGHA ARACCHILAGE Janitha Sura',
#   'Janitha Surath',
#   'Subasingha Aracchilage',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/SUDASINGHA-Pramesh-Prasanna-3022444/',
#   'SUDASINGHA Pramesh Prasanna',
#   'Pramesh Prasanna',
#   'Sudasingha',
#   'Sri Lanka',
#   'SRI',
#   'Volleyball'),
#  ('https://en.asiangames2018.id/athletes/athlete/SUDUSINGHE-Sandaruwan-Priyalanka-3029809/',
#   'SUDUSINGHE Sandaruwan Priyalanka',
#   'Sandaruwan Priyalanka',
#   'Sudusinghe',
#   'Sri Lanka',
#   'SRI',
#   'Hockey'),
#  ('https://en.asiangames2018.id/athletes/athlete/SUREYAARACHCHI-Sudam-Parinda-3013355/',
#   'SUREYAARACHCHI Sudam Parinda',
#   'Sudam Parinda',
#   'Sureyaarachchi',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/THANGARAJAH-Dineshkanthan-3022324/',
#   'THANGARAJAH Dineshkanthan',
#   'DINESHKANTHAN',
#   'THANGARAJAH',
#   'Sri Lanka',
#   'SRI',
#   'Tennis'),
#  ('https://en.asiangames2018.id/athletes/athlete/THANIP-ARACHCHILAGE-Kavindu-Perera-3013140/',
#   'THANIP ARACHCHILAGE Kavindu Perera',
#   'Kavindu Perera',
#   'Thanip Arachchilage',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/THENNAKOON-MUDIYANSELAGE-G-K-H-3013448/',
#   'THENNAKOON MUDIYANSELAGE G. K. H.',
#   'GOTHAMI KAWSHALYA HERATH',
#   'THENNAKOON MUDIYANSELAGE',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/THEVAKUMAR-Arnold-Brent-3024462/',
#   'THEVAKUMAR Arnold Brent',
#   'Arnold Brent',
#   'Thevakumar',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/THEVAKUMAR-Clinton-Stallone-3027868/',
#   'THEVAKUMAR Clinton Stallone',
#   'CLINTON STALLONE',
#   'THEVAKUMAR',
#   'Sri Lanka',
#   'SRI',
#   'Basketball 3x3'),
#  ('https://en.asiangames2018.id/athletes/athlete/THILINI-Hendahewa-3018668/',
#   'THILINI Hendahewa',
#   'HENDAHEWA',
#   'THILINI',
#   'Sri Lanka',
#   'SRI',
#   'Badminton'),
#  ('https://en.asiangames2018.id/athletes/athlete/UDAWATHTHAGE-URU-9957202/',
#   'UDAWATHTHAGE U.R.U.',
#   'UDARA RAMESH UDAWATHTHA',
#   'UDAWATHTHAGE',
#   'Sri Lanka',
#   'SRI',
#   'Rowing'),
#  ('https://en.asiangames2018.id/athletes/athlete/UDUWAKA-HEWAGE-Nelanka-Karunarathna-3013686/',
#   'UDUWAKA HEWAGE Nelanka Karunarathna',
#   'NELANKA KARUNARATHNA',
#   'UDUWAKA HEWAGE',
#   'Sri Lanka',
#   'SRI',
#   'Baseball'),
#  ('https://en.asiangames2018.id/athletes/athlete/UWARAPAKSHA-GEDARA-Rajitha-P-K-3021478/',
#   'UWARAPAKSHA GEDARA Rajitha P. K.',
#   'Rajitha Pushpa Kumara',
#   'UWARAPAKSHA GEDARA',
#   'Sri Lanka',
#   'SRI',
#   'Judo'),
#  ('https://en.asiangames2018.id/athletes/athlete/VITHANA-GAMAGE-Charles-Jesan-D-3013131/',
#   'VITHANA GAMAGE Charles Jesan D.',
#   'Charles Jesan Dissanayake',
#   'Vithana Gamage',
#   'Sri Lanka',
#   'SRI',
#   'Rugby Sevens'),
#  ('https://en.asiangames2018.id/athletes/athlete/WAHUMPURA-GEDARA-Sajini-Manori-J-3013611/',
#   'WAHUMPURA GEDARA Sajini Manori J.',
#   'SAJINI MANORI JAYASINGHE',
#   'WAHUMPURA GEDARA',
#   'Sri Lanka',
#   'SRI',
#   'Kabaddi'),
#  ('https://en.asiangames2018.id/athletes/athlete/WALIWARSHA-KONDA-LIYANA-ARACHCHIGE-Nimali-3018532/',
#   'WALIWARSHA KONDA LIYANA ARACHCHIGE Nimali',
#   'Nimali',
#   'Waliwarsha Konda Liyana A',
#   'Sri Lanka',
#   'SRI',
#   'Athletics')]

# %%
athlete = []
requests = 0
start_time = time.time()

name_file = 'AG2018_country_athletes\\ag2018_' + str(7) + '.' + country_ath_df['noc_code'][6].lower() + '_athletes.csv'
noc_ath_df = pd.read_csv(name_file)

for i in range(0, len(noc_ath_df)):
    bio = []
    social = []
    
    ath_url = noc_ath_df['url'][i]
    ath_response = get(ath_url)
    ath_soup = BeautifulSoup(ath_response.text, 'html.parser')

    
    sleep(randint(1,4))
    requests += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)    
    
    name = ath_soup.find('span', class_ = 'or-athlete-profile__name--name').text
    surname = ath_soup.find('span', class_ = 'or-athlete-profile__name--surname').text
    nationality = ath_soup.find('span', class_ = 'or-athlete-profile__nationality--noc').text
    discipline = ath_soup.find('div', class_ = 'or-athlete-profile__discipline').text
    birth_date = ath_soup.find('span', class_ = 'or-athlete__birth--date').text
    birth_city = ath_soup.find('span', class_ = 'or-athlete__birth--city').text
    
    if ath_soup.find('span', class_ = 'or-athlete__birth--country') is not None:
        birth_country = ath_soup.find('span', class_ = 'or-athlete__birth--country').text
    else: birth_country = ''
    
    age = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[0].text
    height = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[2].text
    weight = ath_soup.find_all('div', class_ = 'or-anagraphic__data')[3].text
    
    birth_country = birth_country[1:-1]
    age = age.replace(' ', '')
    age = age.replace('\r\n', '')
    height = height.replace(' ', '')
    height = height.replace('\r', '')
    height = height.replace('\n', '')
    if (height == '-/-'):
        height_cm = ''
        height = ''
    else:
        height_cm = height[0:height.find("CM")] #kalau height = '-/...' atau height.find("CM") == -1, maka akan menyimpan nilai '-/'
        height = height[len(height_cm) + 3:] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    weight = weight.replace(' ', '')
    weight = weight.replace('\r', '')
    weight = weight.replace('\n', '')
    if (weight == '-/-'):
        weight_kg = ''
        weight_lbs = ''
    else:
        weight_kg = weight[0:weight.find("kg")] #kalau weight = '-/...' atau weight.find("kg") == -1, maka akan menyimpan nilai '-/'
        weight_lbs = weight[weight.find("kg") + 3:weight.find("lbs")] #sudah benar nampaknya... #perlu dicek lagi kalau algoritma yang di atas ini diganti
    
    
    src_containers = ath_soup.find_all('orp')
    
    medal_containers = src_containers[0]
    ath_medal_url = medal_containers['src']


    sleep(randint(1,2))

    
    response = get(ath_medal_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup.find_all('td', class_ = 'or-table-medals__b--medal') != []:
        gold = soup.find_all('td', class_ = 'or-table-medals__b--medal')[0].text
        silver = soup.find_all('td', class_ = 'or-table-medals__b--medal')[1].text
        bronze = soup.find_all('td', class_ = 'or-table-medals__b--medal')[2].text
    else:
        gold = 0
        silver = 0
        bronze = 0
    
    bio_containers = src_containers[1]
    bio_url = bio_containers['src']
    bio_response = get(bio_url)
    bio_soup = BeautifulSoup(bio_response.text, 'html.parser')


    sleep(randint(1,2))

    
    bio_containers = bio_soup.find_all('div', class_ ='or-article__part markdown')
    
    for j in range(0, len(bio_containers)):
        subtitle = bio_containers[j].h2.text #Perlu lebih dirapikan di bagian ini
        content = bio_containers[j].p.text #ada b, ada br, ada \n
        if (subtitle == 'Social'):
            socmed_containers = bio_containers[j].find_all('li')
            for k in range(0, len(socmed_containers)):
                social.append((socmed_containers[k].a['href']))
        else:
            bio.append((subtitle, content))
        
        
    athlete.append((ath_url, name, surname, nationality, discipline, birth_date, birth_city, birth_country, age, height_cm, height, weight_kg, weight_lbs, int(gold), int(silver), int(bronze), bio, social, bio_url))
    #height_cm, weight_kg, dan weight_lbs belum jadi int karena bisa berisikan '-' #kasus #351
    #age belum jadi int karena berisikan '\n' #kasus #768
# Out:
# Request:893; Frequency: 0.13196219099224107 requests/s

# %%
len(athlete)
# Out:
# 893

# %%
athlete_chn_df = pd.DataFrame(athlete, columns = ['url','name', 'surname', 'nationality', 'discipline', 'birth_date', 'birth_city', ' birth_country', 'age', 'height_cm', 'height', 'weight_kg', 'weight_lbs', 'gold', 'silver', 'bronze', 'bio', 'social', 'bio_url'])
athlete_chn_df.to_csv('ag2018_athletes_chn.csv', index = False)

# %% [markdown]
# # Coba yang lain

# %%
# specify the url
quote_page = 'https://en.asiangames2018.id/athletes/athlete/SUN-Yang-3008844'

# %%
# query the website and return the html to the variable ‘page’
page = urllib.request.urlopen(quote_page)

# %%
print(page)
# Out:
# <http.client.HTTPResponse object at 0x000001DD89D49470>

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')

# %%
# Take out the <div> of name and get its value
age_box = soup.find('div', attrs={'class': 'or-anagraphic__data'})

# %%
age = age_box.text.strip() # strip() is used to remove starting and trailing
print(age)
# Out:
# 26

# %%
name_box = soup.find('span', attrs={'class': 'or-athlete-profile__name--name'})
surname_box = soup.find('span', attrs={'class': 'or-athlete-profile__name--surname'})
nationality_box = soup.find('span', attrs={'class': 'or-athlete-profile__nationality--noc'})
discipline_box = soup.find('div', attrs={'class': 'or-athlete-profile__discipline'})

# %%
date_box = soup.find('span', attrs={'class': 'or-athlete__birth--date'})
city_box = soup.find('span', attrs={'class': 'or-athlete__birth--city'})
country_box = soup.find('span', attrs={'class': 'or-athlete__birth--country'})

# %%
name = name_box.text.strip()
surname = surname_box.text.strip()
nationality = nationality_box.text.strip()
discipline = discipline_box.text.strip()
date = date_box.text.strip()
city = city_box.text.strip()
country = country_box.text.strip()

# %%
import csv
from datetime import datetime

# %%
# open a csv file with append, so old data will not be erased
with open('index.csv', 'a') as csv_file:
 writer = csv.writer(csv_file)
 writer.writerow([name, surname, nationality, discipline, age, date, city, country, datetime.now()])

# %%
article_box = soup.find('article')

# %%
print(article_box)
# Out:
# None

# %%
article = article_box.text.strip()
print(article)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-2b51d2c0d119> in <module>()
# ----> 1 article = article_box.text.strip()
#       2 print(article)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
article2_box = soup.find('div', attrs={'class': 'or-article__part markdown'})

# %%
article2 = article2_box.text.strip()
print(article2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-4f94a8878d2d> in <module>()
# ----> 1 article2 = article2_box.text.strip()
#       2 print(article2)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# # Multiple Indices

# %%
quote_page = [‘http://www.bloomberg.com/quote/SPX:IND', ‘http://www.bloomberg.com/quote/CCMP:IND']

# %%
# for loop
data = []

for pg in quote_page:
 # query the website and return the html to the variable ‘page’
 page = urllib2.urlopen(pg)

# parse the html using beautiful soap and store in variable `soup`
 soup = BeautifulSoup(page, ‘html.parser’)

# Take out the <div> of name and get its value
 name_box = soup.find(‘h1’, attrs={‘class’: ‘name’})
 name = name_box.text.strip() # strip() is used to remove starting and trailing

# get the index price
 price_box = soup.find(‘div’, attrs={‘class’:’price’})
 price = price_box.text

# save the data in tuple
 data.append((name, price))

# %%
# open a csv file with append, so old data will not be erased
with open(‘index.csv’, ‘a’) as csv_file:
 writer = csv.writer(csv_file)
 # The for loop
 for name, price in data:
 writer.writerow([name, price, datetime.now()])

# %% [markdown]
# # Coba pakai requests get()

# %%
url = 'https://en.asiangames2018.id/athletes/athlete/XU-Jiayu-3008858/'
response = get(url)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#
#
#
#
#
#
#
#
# <title>XU Jiayu | Asian Games 2018 Jakarta Palembang</title>
#
#     <meta property="description" content="Over 10,000 athletes from all National Olympic Committees in Asia will be participating in the Asian Games 2018 Jakarta-Palembang" />
#
#     <meta property="olydata:organisation" content="CHN" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="Asian Games 2018 Jakarta Palembang" />
# <meta name="twitter:domain" content="https://en.asiangames2018.id/" />
#
# <meta property="og:title" content="XU Jiayu | Asian Games 2018 Jakarta Palembang" />
# <meta property="og:description" content="Over 10,000 athletes from all National Olympic Committees in Asia will be participating in the Asian Games 2018 Jakarta-Palembang" />
# <meta property="og:url" content="https://en.asiangames2018.id//athletes/athlete/xu-jiayu-3008858/" />
# <meta property="og:site_name" content="Asian Games 2018 Jakarta Palembang" />
# <meta property="og:type" content="website" />
# <meta property="og:image" content="https://externalmodules.asiangames2018.id/en/25/images/athletes/xl/3008858.png" />
#
#
#
# <meta name="gsa:title" content="XU Jiayu | Asian Games 2018 Jakarta Palembang" />
# <meta name="description" content="Over 10,000 athletes from all National Olympic Committees in Asia will be participating in the Asian Games 2018 Jakarta-Palembang" />
#
# <meta name="availableOn" content="all" />
#
#
#
#     <meta property="fb:app_id" content="">
#
#
#
# <script type="text/javascript">
#
#   window.deltatreconf = {
#       orp: {
#           widget: {
#               scorePollingPath: 'https://externalmodules.asiangames2018.id/en/live/25/widget/[discipline]/[event]/[unit]/scoreforge.json'
#           },
#       tzc: {
#         timeFormat: '{h}:{mm}{_am}',
#         dateFormat: '{%d-suff} {%ms}',
#         deltaGMT : 7
#         },
#       medals: {
#         format_time: 'as of {ddd}, {dd}th {MMMM} {hh}:{mm}'
#       },
#       redirector: {
#         enabled: true,
#           url_roles: [
#             { 'regexp': '/schedule-results/overview', 'replace': '/schedule-results', 'mq': '(max-width: 899px)' },
#             { 'regexp': '/schedule-results/qualification-overview', 'replace': '/schedule-results/qualification', 'mq': '(max-width: 899px)' }
#           ]
#       },
#       tzcDateFormat : {
#         daysInWeek: ['Sunday',
#           'Monday',
#           'Tuesday',
#           'Wednesday',
#           'Thursday',
#           'Friday',
#           'Saturday'],
#         daysInWeekShort: ['Sun',
#           'Mon',
#           'Tue',
#           'Wed',
#           'Thu',
#           'Fri',
#           'Sat'],
#         shortMonthsInYear: ['Jan',
#           'Feb',
#           'Mar',
#           'Apr',
#           'May',
#           'Jun',
#           'Jul',
#           'Aug',
#           'Sep',
#           'Oct',
#           'Nov',
#           'Dec'],
#         longMonthsInYear: ['January',
#           'February',
#           'March',
#           'April',
#           'May',
#           'June',
#           'July',
#           'August',
#           'September',
#           'October',
#           'November',
#           'December'],
#         shortMonthsToNumber: {
#           'Jan': '1',
#           'Feb': '2',
#           'Mar': '3',
#           'Apr': '4',
#           'May': '5',
#           'Jun': '6',
#           'Jul': '7',
#           'Aug': '8',
#           'Sep': '9',
#           'Oct': '10',
#           'Nov': '11',
#           'Dec': '12'
#         }
#         }
#       }
#     }
#
# </script>
#
#
#
#
#
#
# <link rel="apple-touch-icon" sizes="57x57" href="/d3images/ml/ag2018-assets//favicon/apple-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="60x60" href="/d3images/ml/ag2018-assets//favicon/apple-icon-60x60.png">
# <link rel="apple-touch-icon" sizes="72x72" href="/d3images/ml/ag2018-assets//favicon/apple-icon-72x72.png">
# <link rel="apple-touch-icon" sizes="76x76" href="/d3images/ml/ag2018-assets//favicon/apple-icon-76x76.png">
# <link rel="apple-touch-icon" sizes="114x114" href="/d3images/ml/ag2018-assets//favicon/apple-icon-114x114.png">
# <link rel="apple-touch-icon" sizes="120x120" href="/d3images/ml/ag2018-assets//favicon/apple-icon-120x120.png">
# <link rel="apple-touch-icon" sizes="144x144" href="/d3images/ml/ag2018-assets//favicon/apple-icon-144x144.png">
# <link rel="apple-touch-icon" sizes="152x152" href="/d3images/ml/ag2018-assets//favicon/apple-icon-152x152.png">
# <link rel="apple-touch-icon" sizes="180x180" href="/d3images/ml/ag2018-assets//favicon/apple-icon-180x180.png">
# <link rel="icon" type="image/png" sizes="192x192" href="/d3images/ml/ag2018-assets//favicon/android-icon-192x192.png">
# <link rel="icon" type="image/png" sizes="32x32" href="/d3images/ml/ag2018-assets//favicon/favicon-32x32.png">
# <link rel="icon" type="image/png" sizes="96x96" href="/d3images/ml/ag2018-assets//favicon/favicon-96x96.png">
# <link rel="icon" type="image/png" sizes="16x16" href="/d3images/ml/ag2018-assets//favicon/favicon-16x16.png">
# <meta name="msapplication-TileColor" content="#ffffff">
# <meta name="msapplication-TileImage" content="/d3images/ml/ag2018-assets//favicon/ms-icon-144x144.png">
# <meta name="theme-color" content="#ffffff">
#
#     <script>
#         window.fbAsyncInit = function () {
#           FB.init({
#             appId: '',
#             autoLogAppEvents: true,
#             xfbml: true,
#             version: 'v2.11'
#           });
#         };
#
#         (function (d, s, id) {
#           var js, fjs = d.getElementsByTagName(s)[0];
#           if (d.getElementById(id)) { return; }
#           js = d.createElement(s); js.id = id;
#           js.src = "https://connect.facebook.net/en_US/sdk.js";
#           fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#     </script>
#
#
#
#
#
#
#
# <link rel="stylesheet" type="text/css" href="https://en.asiangames2018.id/d3components/styles/base.min.css?v=32" />
#
#             <link rel="stylesheet" type="text/css" href="https://en.asiangames2018.id/d3components/styles/orp-schedules-results.min.css?v=32" />
#             <link rel="stylesheet" type="text/css" href="https://en.asiangames2018.id/d3components/styles/orp-athletes.min.css?v=32" />
#
# <link rel="stylesheet" type="text/css" href="https://en.asiangames2018.id/d3components/styles/hotfix.min.css?v=32" />
#
#
#
#
#
# <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/tophead.min.js?v=24"></script>
# <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/subhead.min.js?v=24"></script>
# <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/head.min.js?v=24"></script>
# <script type="text/javascript" charset="utf-8" src="https://agp2018.net/soc.php" async></script>
#
#
#
#
#
#
#
#
#
#
#     <!-- Google Analytics -->
#     <script>
#         window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#         ga('create', 'UA-121059222-1', 'auto');
#         ga('send', 'pageview');
#     </script>
#     <script async src='https://www.google-analytics.com/analytics.js'></script>
#     <!-- End Google Analytics -->
#
#
# </head>
# <body class="games-time">
#     <!--googleoff: all-->
#
#     <div class="or-page-wrapper" id="wrapper">
#
#
# <nav class="or-podium or-skipToLinks">
#     <a class="or-skipto or-js-skip" href="#content">Skip to main</a>
# </nav>
#
# <header id="ag2018__header">
#     <div class="ag2018-header__upper-wrapper">
#         <div class="ag2018-header__container ag2018-header__container--upper">
#
#
# <nav class="or-nav-secondary">
#     <h2 class="or-sr-only">Secondary menu</h2>
#     <ul class="or-nav-secondary__list">
#
#             <li class="or-nav-secondary__item">
#                 <a href="/about/ticketing" target="_blank">Tickets</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="https://www.character-land.com/karakter/asian-games-2018" target="_blank">Shop</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#
#
# <nav class="or-nav-social">
#     <h2 class="or-sr-only">Social menu</h2>
#     <ul class="or-nav-social__list">
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.facebook.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--facebook"></span>
#                     <span class="or-sr-only">Facebook</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://twitter.com/asiangames2018" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--twitter"></span>
#                     <span class="or-sr-only">Twitter</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.instagram.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--instagram"></span>
#                     <span class="or-sr-only">Instagram</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.youtube.com/channel/UC7oWYw9vZbkDwCi81hJpZTQ" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--youtube"></span>
#                     <span class="or-sr-only">YouTube</span>
#                 </a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#         </div>
#     </div>
#     <div class="ag2018-header__lower-wrapper">
#         <div class="ag2018-header__container ag2018-header__container--lower">
#             <h1 class="ag2018-header__logo">
#                 <a href="/">
#                     <span class="or-sr-only">18th Asian Games Jakarta Palembang 2018</span>
#                 </a>
#             </h1>
#             <div class="ag2018-header__nav">
#
#
# <nav class="or-nav-top">
#     <h2 class="or-sr-only">Main menu</h2>
#     <ul class="or-nav-top__list">
#
#                 <li class="or-nav-top__item  ">
#                     <a href="/">Home</a>
#                 </li>
#                 <li class="or-nav-top__item pinned ">
#                     <a href="/schedule-results/">Schedule &amp; Results</a>
#                 </li>
#                 <li class="or-nav-top__item pinned hiddenMob">
#                     <a href="/news/">News</a>
#                 </li>
#                 <li class="or-nav-top__item pinned ">
#                     <a href="/medals/">Medals</a>
#                 </li>
#                 <li class="or-nav-top__item pinned ">
#                     <a href="/sport/">Sports</a>
#                 </li>
#                 <li class="or-nav-top__item  ">
#                     <a href="/athletes/">Athletes</a>
#                 </li>
#                 <li class="or-nav-top__item   or-nav-top__item--dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">About Asian Games<span class="dropdown-icon" aria-hidden="true"></span></a>
#                     <ul class="or-nav-top__dropdown-list">
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/ticketing">Tickets</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/">About</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/history">History</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/inasgoc">INASGOC</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/mascots">Mascots</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/opening-ceremony">Opening Ceremony</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/closing-ceremony">Closing Ceremony</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/our-apps">Our apps</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/partners">Partners</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/about/important-information">Important Information</a>
#                             </li>
#                     </ul>
#                 </li>
#                 <li class="or-nav-top__item   or-nav-top__item--dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">Traffic Adjustment<span class="dropdown-icon" aria-hidden="true"></span></a>
#                     <ul class="or-nav-top__dropdown-list">
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/traffic/jakarta-cluster-1">Jakarta Cluster 1</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/traffic/jakarta-cluster-2">Jakarta Cluster 2</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/traffic/jakarta-suburbs">Jakarta Suburbs</a>
#                             </li>
#                             <li class="or-nav-top__dropdown-item">
#                                 <a href="/traffic/palembang">Palembang</a>
#                             </li>
#                     </ul>
#                 </li>
#     </ul>
# </nav>
#             </div>
#             <div class="ag2018-header__lang">
#
#
#
#
# <nav class="or-nav-lang">
#     <h2 class="or-sr-only">Language menu</h2>
#     <a class="or-nav-lang__toggle or-js-langToggle" role="button" aria-haspopup="true" aria-expanded="false" href="#" aria-label="Current language is english. Click to change">
#         <span class="or-nav-lang__label">English </span>
#         <span class="or-nav-lang__abbr">Eng </span>
#         <span class="dropdown-icon" aria-hidden="true"></span>
#     </a>
#     <ul class="or-nav-lang__list">
#
#             <li class="or-nav-lang__item">
#                 <a href="https://id.asiangames2018.id/" data-jshook="language-switch" data-culture="id-ID">Bahasa Indonesia</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#             </div>
#             <div class="ag2018-header__sidebar-toggle">
#                 <a role="button" class="or-hamburger or-js-hamburger" id="ag2018-hamburgher" href="#ag2018-sidebar">
#                     <span class="or-hamburger__bar"> </span>
#                     <span class="or-hamburger__bar"> </span>
#                     <span class="or-hamburger__bar"> </span>
#                     <span class="or-sr-only">Menu</span>
#                 </a>
#             </div>
#
#         </div>
#     </div>
# </header>
# <div id="ag2018-sidebar">
#     <div class="ag2018-sidebar__innersleeve">
#
#
# <nav class="or-nav-sidebar">
#     <h2 class="or-sr-only">Main menu</h2>
#     <ul class="or-nav-sidebar__list">
#
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/">Home</a>
#                 </li>
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/schedule-results/">Schedule &amp; Results</a>
#                 </li>
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/news/">News</a>
#                 </li>
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/medals/">Medals</a>
#                 </li>
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/sport/">Sports</a>
#                 </li>
#                 <li class="or-nav-sidebar__item ">
#                     <a href="/athletes/">Athletes</a>
#                 </li>
#                 <li class="or-nav-sidebar__item  or-nav-sidebar__item--dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="sidebar-dropdown" role="button" aria-haspopup="true" aria-expanded="false">About Asian Games<span class="dropdown-icon" aria-hidden="true"></span></a>
#                     <ul class="or-nav-sidebar__dropdown-list">
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/ticketing">Tickets</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/">About</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/history">History</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/inasgoc">INASGOC</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/mascots">Mascots</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/opening-ceremony">Opening Ceremony</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/closing-ceremony">Closing Ceremony</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/our-apps">Our apps</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/partners">Partners</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/about/important-information">Important Information</a>
#                             </li>
#                     </ul>
#                 </li>
#                 <li class="or-nav-sidebar__item  or-nav-sidebar__item--dropdown">
#                     <a href="#" class="dropdown-toggle" data-toggle="sidebar-dropdown" role="button" aria-haspopup="true" aria-expanded="false">Traffic Adjustment<span class="dropdown-icon" aria-hidden="true"></span></a>
#                     <ul class="or-nav-sidebar__dropdown-list">
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/traffic/jakarta-cluster-1">Jakarta Cluster 1</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/traffic/jakarta-cluster-2">Jakarta Cluster 2</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/traffic/jakarta-suburbs">Jakarta Suburbs</a>
#                             </li>
#                             <li class="or-nav-sidebar__dropdown-item">
#                                 <a href="/traffic/palembang">Palembang</a>
#                             </li>
#                     </ul>
#                 </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#
#
#
# <nav class="or-nav-social">
#     <h2 class="or-sr-only">Social menu</h2>
#     <ul class="or-nav-social__list">
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.facebook.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--facebook"></span>
#                     <span class="or-sr-only">Facebook</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://twitter.com/asiangames2018" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--twitter"></span>
#                     <span class="or-sr-only">Twitter</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.instagram.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--instagram"></span>
#                     <span class="or-sr-only">Instagram</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.youtube.com/channel/UC7oWYw9vZbkDwCi81hJpZTQ" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--youtube"></span>
#                     <span class="or-sr-only">YouTube</span>
#                 </a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#
#
#
#
#
# <nav class="or-nav-lang">
#     <h2 class="or-sr-only">Language menu</h2>
#     <a class="or-nav-lang__toggle or-js-langToggle" role="button" aria-haspopup="true" aria-expanded="false" href="#" aria-label="Current language is english. Click to change">
#         <span class="or-nav-lang__label">English </span>
#         <span class="or-nav-lang__abbr">Eng </span>
#         <span class="dropdown-icon" aria-hidden="true"></span>
#     </a>
#     <ul class="or-nav-lang__list">
#
#             <li class="or-nav-lang__item">
#                 <a href="https://id.asiangames2018.id/" data-jshook="language-switch" data-culture="id-ID">Bahasa Indonesia</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#
#
#
# <nav class="or-nav-secondary">
#     <h2 class="or-sr-only">Secondary menu</h2>
#     <ul class="or-nav-secondary__list">
#
#             <li class="or-nav-secondary__item">
#                 <a href="/about/ticketing" target="_self">Tickets</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="https://www.character-land.com/karakter/asian-games-2018" target="_self">Shop</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="/terms-of-service" target="_self">Terms of Service</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="/privacy-policy" target="_self">Privacy Policy</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="/cookie-policy" target="_self">Cookie Policy</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#     </div>
# </div>
#
#         <main id="content" name="content">
#
#                 <div class="d3-container-content" ng-app="ES-App">
#                     <div class="dcm-w or-podium" id="or-wrap">
#                         <div id="orp-main" role="main">
#                             <div class="dcm-cW">
#
#
#
# <div class="page-wrap">
#     <div class="g11__container">
#
#
#
#
#
#
# <div class="or-sectionheader ">
#     <h1 class="or-sectionheader__title">Athletes</h1>
#         <div class="or-sectionheader__search">
#
#
#
#
# <div class="or-searchbox">
#     <div class="or-searchbox__wrapper">
#         <span class="ico-mglass"></span>
#         <input class="or-searchbox__input js-athlete-search" data-search-url="/athletes/search" type="search" placeholder="Search" />
#     </div>
# </div>
#
#
#
#         </div>
#     </div>
#
#
#
#
#
# <div class="or-athlete-profile__wrapper">
#     <div class="or-athlete-profile__box">
#         <div class="or-athlete-profile">
#             <div class="or-athlete-profile__card">
#                 <figure class="or-athlete-profile__pic">
#                     <img src="https://externalmodules.asiangames2018.id/en/25/images/athletes/xl/3008858.png" alt="XU Jiayu" title="XU Jiayu" onerror="this.src='https://en.asiangames2018.id//d3images/ml/athletes/silhouette/or-athlete__silhouette--gM.svg'" />
#                 </figure>
#                 <div class="or-athlete-profile__info">
#                     <div class="or-athlete-profile__name">
#                         <span class="or-athlete-profile__name--name">JIAYU</span>
#                         <span class="or-athlete-profile__name--surname">XU</span>
#                     </div>
#                     <div class="or-athlete-profile__nationality">
#                         <img src="/d3images/ml/flags/s/CHN.png" alt="China"
#                              title="China" class="or-athlete-profile__nationality--flag" />
#                         <span class="or-athlete-profile__nationality--noc">CHN</span>
#                     </div>
#                     <div class="or-athlete-profile__sport">
#                         <div class="or-athlete-profile__sport-img">
#                             <span class="or-athlete-profile__picto or-pic or-sw"></span>
#                         </div>
#                         <div class="or-athlete-profile__discipline">Swimming</div>
#                     </div>
#                 </div>
#             </div>
#             <div class="or-athlete-profile__moreinfo">
#                 <div class="or-athlete-profile__anagraphic">
#                     <div class="or-anagraphic__row">
#                         <div class="or-anagraphic__block">
#                             <div class="or-anagraphic__label">
#                                 Age
#                             </div>
#                             <div class="or-anagraphic__data">
#                                 23
#                             </div>
#                         </div>
#                         <div class="or-anagraphic__block">
#                             <div class="or-anagraphic__label">
#                                 Born
#                             </div>
#                             <div class="or-anagraphic__data">
#                                 <span class="or-athlete__birth--date">08/19/1995</span>
#                                 <span class="or-athlete__birth--city"></span>
#                                     <span class="or-athlete__birth--country">(China)</span>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="or-anagraphic__row">
#                         <div class="or-anagraphic__block">
#                             <div class="or-anagraphic__label">
#                                 Height
#                             </div>
#                             <div class="or-anagraphic__data">
#                                 184
#                                     <span class="or-anagraphic__unit">CM</span>
#  / 6&#39;0&quot;
#                             </div>
#                         </div>
#                         <div class="or-anagraphic__block">
#                             <div class="or-anagraphic__label">
#                                 Weight
#                             </div>
#                             <div class="or-anagraphic__data">
#                                 72
#                                     <span class="or-anagraphic__unit">kg</span>
#  / 159
#                                     <span class="or-anagraphic__unit">lbs</span>
#                             </div>
#                         </div>
#                     </div>
#
#                 </div>
#                 <orp type="ssinc" src="https://externalmodules.asiangames2018.id/en/25/athletes/3008858/medal.html"></orp>
#
#             </div>
#
#             <orp type="ssinc" src="https://externalmodules.asiangames2018.id/en/25/bio/athletes/bio_3008858.html"></orp>
#         </div>
#     </div>
# </div>
#
#
#
#
#
#
#
#     </div>
# </div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#
#                     <div class="or-share-this__bottomwrapper">
#
#
#
#
# <div class="or-share-this">
#     <button class="or-share-this__toggle" data-toggle="collapse" role="button" aria-expanded="false" aria-controls="sharebox-1507933414" data-target="#sharebox-1507933414">Share this page</button>
#     <div class="or-share-this__box collapse" id="sharebox-1507933414">
#         <div class="addthis_sharing_toolbox" data-url="https://en.asiangames2018.id//athletes/athlete/xu-jiayu-3008858/" data-title="" data-description="" data-media="https://externalmodules.asiangames2018.id/en/25/images/athletes/xl/3008858.png">
#             <a aria-label="Facebook" class="addthis_button_facebook or-share-this__btn or-share-this__btn--facebook"><i class="fa fa-facebook" aria-hidden="true"></i></a>
#             <a aria-label="Twitter" class="addthis_button_twitter or-share-this__btn or-share-this__btn--twitter"><i class="fa fa-twitter" aria-hidden="true"></i></a>
#             <a aria-label="Whatsapp" class="addthis_button_whatsapp or-share-this__btn or-share-this__btn--whatsapp"><i class="fa fa-whatsapp" aria-hidden="true"></i></a>
#         </div>
#     </div>
# </div>
#
#                     </div>
#
#         </main>
#
#
#
#
#
# <footer id="ag2018__footer" class="ag2018-footer">
#     <div class="ag2018-footer__upper-wrapper">
#         <div class="ag2018-footer__container">
#
#             <div class="ag2018-footer__row1">
#
#
# <nav class="or-nav-bottom">
#     <h2 class="or-sr-only">Main menu</h2>
#
#     <ul class="or-nav-bottom__list">
#
#             <li class="or-nav-bottom__item ">
#                 <a href="/">Home</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="/schedule-results/">Schedule &amp; Results</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="/news/">News</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="/medals/">Medals</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="/sport/">Sports</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="/athletes/">Athletes</a>
#             </li>
#             <li class="or-nav-bottom__item hidden">
#                 <a href="#">About Asian Games</a>
#             </li>
#             <li class="or-nav-bottom__item ">
#                 <a href="#">Traffic Adjustment</a>
#             </li>
#     </ul>
#
#
#             <ul class="or-nav-bottom__about-list">
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/ticketing">Tickets</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/">About</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/history">History</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/inasgoc">INASGOC</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/mascots">Mascots</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/opening-ceremony">Opening Ceremony</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/closing-ceremony">Closing Ceremony</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/our-apps">Our apps</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/partners">Partners</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/about/important-information">Important Information</a>
#                     </li>
#             </ul>
#             <ul class="or-nav-bottom__about-list">
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/traffic/jakarta-cluster-1">Jakarta Cluster 1</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/traffic/jakarta-cluster-2">Jakarta Cluster 2</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/traffic/jakarta-suburbs">Jakarta Suburbs</a>
#                     </li>
#                     <li class="or-nav-bottom__about-item">
#                         <a href="/traffic/palembang">Palembang</a>
#                     </li>
#             </ul>
#
# </nav>
#
#
#
#
#
#
#
#             </div>
#
#             <div class="ag2018-footer__row2">
#                 <div class="ag2018-footer__langnav">
#
#
#
#
# <nav class="or-nav-lang">
#     <h2 class="or-sr-only">Language menu</h2>
#     <a class="or-nav-lang__toggle or-js-langToggle" role="button" aria-haspopup="true" aria-expanded="false" href="#" aria-label="Current language is english. Click to change">
#         <span class="or-nav-lang__label">English </span>
#         <span class="or-nav-lang__abbr">Eng </span>
#         <span class="dropdown-icon" aria-hidden="true"></span>
#     </a>
#     <ul class="or-nav-lang__list">
#
#             <li class="or-nav-lang__item">
#                 <a href="https://id.asiangames2018.id/" data-jshook="language-switch" data-culture="id-ID">Bahasa Indonesia</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#                 </div>
#
#                 <div class="ag2018-footer__secondary-nav">
#
#
# <nav class="or-nav-secondary">
#     <h2 class="or-sr-only">Secondary menu</h2>
#     <ul class="or-nav-secondary__list">
#
#             <li class="or-nav-secondary__item">
#                 <a href="/about/ticketing" target="_blank">Tickets</a>
#             </li>
#             <li class="or-nav-secondary__item">
#                 <a href="https://www.character-land.com/karakter/asian-games-2018" target="_blank">Shop</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#                 </div>
#
#                 <div class="ag2018-footer__social-nav">
#
#
# <nav class="or-nav-social">
#     <h2 class="or-sr-only">Social menu</h2>
#     <ul class="or-nav-social__list">
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.facebook.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--facebook"></span>
#                     <span class="or-sr-only">Facebook</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://twitter.com/asiangames2018" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--twitter"></span>
#                     <span class="or-sr-only">Twitter</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.instagram.com/asiangames2018/" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--instagram"></span>
#                     <span class="or-sr-only">Instagram</span>
#                 </a>
#             </li>
#             <li class="or-nav-social__item  ">
#                 <a href="https://www.youtube.com/channel/UC7oWYw9vZbkDwCi81hJpZTQ" target="_blank">
#                     <span class="or-nav-social__icon or-nav-social__icon--youtube"></span>
#                     <span class="or-sr-only">YouTube</span>
#                 </a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>
#     <div class="ag2018-footer__lower-wrapper">
#         <div class="ag2018-footer__container">
#             <div class="ag2018-footer__bottom-nav">
#
#
#
#
# <nav class="or-nav-lower">
#     <ul class="or-nav-lower__list">
#             <li class="or-nav-lower__item">
#                 <a href="/terms-of-service">Terms of Service</a>
#             </li>
#             <li class="or-nav-lower__item">
#                 <a href="/cookie-policy">Cookie Policy</a>
#             </li>
#             <li class="or-nav-lower__item">
#                 <a href="/privacy-policy">Privacy Policy</a>
#             </li>
#     </ul>
# </nav>
#
#
#
#
#
#
#
#             </div>
#             <div class="ag2018-footer__copyright">
#                 &#169; Copyright 2018. All rights reserved
#             </div>
#         </div>
#     </div>
# </footer>
#     </div>
#     <!--googleon: all-->
#
#
#
#
#                 <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/ng-apps/es-app.js?v=24"></script>
#
#
#
#
#
# <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/addons.min.js?v=24"></script>
#
#
#
# <script type="text/javascript" charset="utf-8" src="https://en.asiangames2018.id/d3components/scripts/main.min.js?v=24"></script>
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5952522e9e1ae25b"></script>
#
# </body>
# </html>

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
article_containers = html_soup.find_all('orp')

# %%
print(type(article_containers))
print(len(article_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 2

# %%
print(article_containers)
# Out:
# [<orp src="https://externalmodules.asiangames2018.id/en/25/athletes/3008858/medal.html" type="ssinc"></orp>, <orp src="https://externalmodules.asiangames2018.id/en/25/bio/athletes/bio_3008858.html" type="ssinc"></orp>]

# %%
medal_containers = article_containers[0]

# %%
medal_containers
# Out:
# <orp src="https://externalmodules.asiangames2018.id/en/25/athletes/3008858/medal.html" type="ssinc"></orp>

# %%
medal_containers['src']
# Out:
# 'https://externalmodules.asiangames2018.id/en/25/athletes/3008858/medal.html'

# %%
biography_containers = article_containers[1]
biography_containers['src']
# Out:
# 'https://externalmodules.asiangames2018.id/en/25/bio/athletes/bio_3008858.html'

# %%
bio_url = biography_containers['src']

# %%
bio_response = get(bio_url)

# %%
bio_html_soup = BeautifulSoup(bio_response.text, 'html.parser')

# %%
bio_containers = bio_html_soup.find_all('div', class_ ='or-article__part markdown')

# %%
print(len(bio_containers))
# Out:
# 15

# %%
for i in range(0,len(bio_containers)):
    print(bio_containers[i].h2.text) #Coba cek juga bio_containers[i].h2
# Out:
# Beginning
# Reason
# Coach
# Ambition
# Memorable
# Awards
# Hero
# Influence
# Relatives
# Nickname
# Education
# Languages
# Hobbies
# Highlights
# Social
